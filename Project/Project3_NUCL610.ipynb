# %% [markdown]
# <a href="https://colab.research.google.com/github/sjtao98/NUCL610/blob/main/Project/Project3_NUCL610.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROJECT 3 - NUCL 610
# # Sn Method and Pn Method

# %% [markdown]
# ## Preparation and Initialization

# %%
import math as m
import cmath as cm
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
from scipy.special import roots_legendre, eval_legendre

# %%
# Global variables to be accessed anywhere
global ng, nregions, geom_length, nmesh_per_region, materials, \
        XS_num, nmesh, geom, xs, BC, \
        s0, s1, s2, curns, phi, adfs, Chi, l, r, ab, tr, nf, scat, even_moments, \
        nx, ny, Dtilda, D_hat, D2tilda, A1, A2, A12, A21, b1, b2, Dc, Keff, iter, iter_max, \
        lamb, lamb_prev, eshift, eshift0, eshift_r, wiel, lamb_s, \
        psi, psid, sf_prev, Am, src,\
        ang_flux

################################################################
#                         Data Input                           #
# ------------------------------------------------------------ #
# ng = number of energy groups                                 #
# nregions = Number of total regions in geometry               #
# materials = List of materials with a length of nmesh         #
# nmesh_per_reg = Number of refined meshes per material region #
# nmesh = Number of total meshes in geometry                   #
# BC = Boundary conditions (0=refl, 1=zero flux, 2=vacuum)     #
################################################################

ng = 2
nregions = 5
geom_length = 100
nmesh_per_region = 20
norder = 4 # For Sn method
#materials  = ['UO2']*nregions
materials  = ['UO2','MOX','UO2','MOX','UO2']
lam_init = 1
wiel = True
show_iter = True
log_plot = True

alpha = 0.5
BC = [0,0] #0: reflective, 2: vacuum
beta_l = 1.0 # left albedo
beta_r = 1.0 # right albedo

data = [[8.873837e-3,	5.424022e-3,	2.332139e-1,	1.592122e-2],
        [6.377025e-2,	9.959442e-2,	8.918111e-1,	0],
        [1.406811e-2, 1.126274e-2,	2.219159e-1,	1.147102e-2],
        [2.691350e-1, 4.577393e-1,	1.043375e+0,	0]]

#solver on and off, 1: Sn, 2 : Pn, else: cmfd-alone
Solver = 1

# Assign enum to XS names
ab   = 0
nf   = 1
tr   = 2
scat = 3
XS_num = 4

# Process input
nmesh = nregions * nmesh_per_region
lmesh = geom_length / nmesh
geom = [lmesh]*nmesh
xs = np.zeros([nmesh, XS_num, ng])
mat_xs = {'UO2':{0:{}, 1:{}, 2:{}, 3:{}}, 'MOX':{0:{}, 1:{}, 2:{}, 3:{}}}

# Initialize matrices
curns   = np.zeros([nmesh,ng])
curns2  = np.zeros([nmesh,ng])

phi     = np.ones([nmesh,ng])
phim0   = np.ones([nmesh,ng]) # phi modified 0 = phi0 + 2*phi2
phi1    = np.ones([nmesh,ng])
phi2    = np.ones([nmesh,ng])
phi3    = np.ones([nmesh,ng])
sf      = np.ones([nmesh])
ss      = np.ones([nmesh])
sf2     = np.ones([nmesh]) # for S tilda 2
ss2     = np.ones([nmesh]) # for S tilda 2
psi     = np.zeros([nmesh])
psid    = np.zeros([nmesh])
sf_prev = np.ones([nmesh])

Dc      = np.ones([nmesh+1,ng])
D_hat   = np.zeros([nmesh+1,ng])
Dtilda  = np.zeros([nmesh+1,ng])
D2tilda = np.zeros([nmesh+1,ng,2]) # left and right

# only 1 in first group of fuel
Chi      = np.ones([nmesh,ng])
Chi[:,1] = .0

# Constants
l = 0 
r = 1
even_moments = True

# Dimensions
nx = nmesh
ny = 1

# Iterations
iter = 0
iter_max = 1000

# Wielandt
# fraction of fission source remaining on RHS after eigenvalue shift
eshift_r = 0.1
# eigenvalue error estimation factor
eshift0  = 10
eshift   = eshift_r

# redefine materials
new_materials = []
for mat in materials:
  for idx in range(nmesh_per_region):
    new_materials.append(mat)

# process xs
for idx,mat in enumerate(mat_xs.keys()):
  offset = idx*ng
  for xs_type in range(XS_num):
    for g in range(ng):
      mat_xs[mat][xs_type][g] = float(data[g+offset][xs_type])
      
# process GEOM
for idx,mat in enumerate(new_materials):
  offset = idx*ng
  for xs_type in range(XS_num):
    for g in range(ng):
      xs[idx][xs_type][g] = mat_xs[mat][xs_type][g]

# Diffusion Coefficients
for idx in range(nmesh):  
  Dc[idx] = 1/3*np.reciprocal(xs[idx][tr])

# process BC
bcval = []
for idx,bc in enumerate(BC):
  if bc == 0:
    bcval.append(0)
  elif bc > 0:
    bcval.append(alpha)
  else:
    print("Error! no negative BC allowed")

# Sources
lamb = lam_init
lamb_prev = 0.1
Keff = 1/lamb
for idx in range(nmesh):
  for g in range(ng):
    sf[idx] = sf[idx] + phi[idx][g]*xs[idx][nf][g]   # fission source
    ss[idx] = ss[idx] + phi[idx][g]*xs[idx][scat][g] # scattering source
  psi[idx] = sum(xs[idx][nf]) * geom[idx]

# P3(0)/CMFD matrix
A1  = np.zeros([nmesh,nmesh])
A2  = np.zeros([nmesh,nmesh])
A12 = np.zeros([nmesh,nmesh])
A21 = np.zeros([nmesh,nmesh])
b1  = np.zeros([nmesh])
b2  = np.zeros([nmesh])
Am  = np.vstack([np.hstack([A1, A21]), np.hstack([A12, A2])])
src = np.hstack([b1,b2])

# P3 matrix for phi2
A1_m2  = np.zeros([nmesh,nmesh])
A2_m2  = np.zeros([nmesh,nmesh])
A12_m2 = np.zeros([nmesh,nmesh])
A21_m2 = np.zeros([nmesh,nmesh])
b1_m2  = np.zeros([nmesh])
b2_m2  = np.zeros([nmesh])
Am_m2  = np.vstack([np.hstack([A1_m2, A21_m2]), np.hstack([A12_m2, A2_m2])])
src_m2 = np.hstack([b1_m2,b2_m2])

# Sn variables
ang_flux = np.ones([nmesh,ng,norder])
surf_ang_flux = np.ones([nmesh+1,ng,norder])
scal_flux = np.ones([nmesh,ng,norder+1])
sn_sf  = np.zeros([nmesh])
sn_ss  = np.zeros([nmesh,ng,norder])
sn_source  = np.zeros([nmesh,ng,norder])
curns_array = np.zeros([nmesh+1,ng])

# %% [markdown]
# ## CMFD

# %%
def UpdateEigen():
  '''
  Updates eigenvalue.
  '''
  global lamb_prev, lamb, sf, psid, psi, Keff, sf_prev, wiel

  lamb_prev = lamb
  if wiel:
    # Multiply eigenvalue shift by <F*flux_n> / <F*flux_n+1>
    gamma_d, gamma_n = 0,0
    for idx in range(nmesh):
      psid[idx] = psi[idx]
      psi[idx]  = sf[idx] * geom[idx]
      gamma_d += psid[idx] * psi[idx]
      gamma_n += psi[idx] * psi[idx]

    # new lambda is original shift + new shift
    lamb = lamb_s + (lamb_prev - lamb_s) * gamma_d/gamma_n

  else:
    # Ordinary way
    lamb = lamb_prev*sum(sf_prev)/sum(sf)
  
  # Determine keff from lambda
  Keff = 1/lamb
  
  return

# %%
def Wiel():
  '''
  Wielandt shift to create new linear system.
  '''
  global eshift, eshift0, eshift_r, lamb, lamb_s, lamb_prev, \
          psi, ss, sf, A1, b1, A2, b2, xs, iter
  
  # Error
  eig_err = abs(lamb - lamb_prev)

  # Calculate shift
  lamb_s = eshift * max(0.3, lamb - eshift0*eig_err)
  lamb_del = lamb - lamb_s

  # Apply shift
  for idx in range(nmesh):
    A1[idx][idx]  -= sum(geom[idx] * xs[idx][nf]) * lamb_s
    fs = psi[idx] * lamb_del
    b1[idx]       = Chi[idx,0] * fs
    b2[idx]       = Chi[idx,1] * fs

  return

# %%
def SetLS():
  '''
  Sets up linear system.
  '''
  global xs, geom, nmesh, A1, A2, A12, A21, D2tilda, sf, ss, lamb, Am, src

  for idx in range(nmesh):
    xst1 = xs[idx][ab][0] + xs[idx][scat][0]
    A1[idx][idx] = geom[idx]*xst1 + D2tilda[idx][0][0] + D2tilda[idx+1][0][1]
    A2[idx][idx] = geom[idx]*xs[idx][ab][1] + D2tilda[idx][1][0] + D2tilda[idx+1][1][1]
    A12[idx][idx] = -geom[idx]*xs[idx][scat][0]
    A21[idx][idx] = 0.0

    # left BC  
    if idx==0: 
      A1[idx][idx+1] = -D2tilda[idx+1][0][0]
      A2[idx][idx+1] = -D2tilda[idx+1][1][0]
    
    # right BC
    elif idx==nmesh-1:
      A1[idx][idx-1] = -D2tilda[idx][0][1]
      A2[idx][idx-1] = -D2tilda[idx][1][1]
    
    # interior
    else:
      A1[idx][idx-1] = -D2tilda[idx][0][1]
      A2[idx][idx-1] = -D2tilda[idx][1][1]
      A1[idx][idx+1] = -D2tilda[idx+1][0][0]
      A2[idx][idx+1] = -D2tilda[idx+1][1][0] 
      
    b1[idx]  = Chi[idx,0] * psi[idx] * lamb
    b2[idx]  = Chi[idx,1] * psi[idx] * lamb

  Am = np.vstack([np.hstack([A1, A21]), np.hstack([A12, A2])])
  src = np.hstack([b1,b2])

  return

# %%
def Normalize():
  '''
  Normalize fliex
  '''
  global phi, phim0, phi1, phi2, phi3

  scale = max(phi[0,:])
  phi[:,0] = phi[:,0]/scale
  phi[:,1] = phi[:,1]/scale
  
  return

# %%
def CMFD():
  '''
  Updates flux between nodal and FDM methods 
  '''
  global geom, phi, lamb, lamb_prev, Dtilda, D_hat, D2tilda, A1, A2, A12, A21, b1, b2, \
          iter, iter_max, nmesh, curns, Keff, wiel, psi, psid, sf, ss, sf_prev, Am, src, SnON, curns_array

  # Initialize error and tolerance
  tol1 = 1E-7
  tol2 = 1E-5
  error1 = np.abs(lamb-lamb_prev)/lamb_prev
  error2 = 0.0
  for idx in range(nmesh):
    sf_change = np.abs(sf[idx] - sf_prev[idx])/sf_prev[idx]
    error2 = max(sf_change,error2)

  # Diffusion Coefficients
  #for idx in range(nmesh):  
    #Dc[idx] = 1/3*np.reciprocal(xs[idx][tr])

  for idx in range(nmesh+1):
    for g in range(ng):
      if idx==0:
        if BC[0] == 0:
          Dtilda[idx][g] = 0.0
        else:
          Dtilda[idx][g] = 1/(1/0.5 + geom[0]/2/Dc[0][g])
      elif idx==nmesh: 
        if BC[1] == 0:
          Dtilda[idx][g] = 0.0
        else:
          Dtilda[idx][g] = 1/(1/0.5 + geom[nmesh-1]/2/Dc[nmesh-1][g])
      else: 
        Dtilda[idx][g] = 1/(geom[idx-1]/2/Dc[idx-1][g] + geom[idx]/2/Dc[idx][g])
  
  # Start outer iteration
  errors = []
  while (error1>tol1):
    if iter >= iter_max:
      print("WARNING: Iteration finished without convergence")
      break
    
    # Run NEM driver
    # NEM_driver()

    # Run Sn/Pn Driver
    if Solver == 1:
      Sn_driver()
    elif Solver == 2:
      Pn_driver()

    # Update D2tilda
    for idx in range(nmesh+1):
      for g in range(ng): 
          D2tilda[idx][g][0] = Dtilda[idx][g] - D_hat[idx][g] # left
          D2tilda[idx][g][1] = Dtilda[idx][g] + D_hat[idx][g] # right
    
    # Sets linear system
    SetLS()

    # Wielandt shift
    if wiel:
      Wiel()

    # Solve linear system
    sol = np.linalg.solve(Am, src)

    phi[:,0] = sol[:nmesh]
    phi[:,1] = sol[nmesh:]


    # Calculate FD currents
    for idx in range(nmesh+1):
      for ig in range(ng):
        if idx == 0:
          curns_array[idx,ig] = D2tilda[idx][g][1]*phi[idx,ig]
        elif idx == nmesh:
          curns_array[idx,ig] = D2tilda[idx][g][0]*phi[idx-1,ig]
        else:
          curns_array[idx,ig] = D2tilda[idx][g][0]*phi[idx-1,ig] + D2tilda[idx][g][1]*phi[idx,ig]
    """
    plt.plot(curns_array[:,0])
    plt.plot(curns_array[:,1])
    plt.legend(["cmfd_curns1","cmfd_curns2"])
    plt.show()
    """
    # Update sources
    sf_prev = sf.copy()
    sf,ss = np.zeros([nmesh]),np.zeros([nmesh])
    for idx in range(nmesh):
      for g in range(ng):
        sf[idx] += phi[idx][g] * xs[idx][nf][g]   # fission source
        # ss[idx] += phi[idx][g] * xs[idx][scat][g] # scattering source
    
    # Update eigenvalue
    UpdateEigen()

    # Update error
    error1 = np.abs(lamb-lamb_prev)/lamb_prev
    error2 = 0.0
    for idx in range(nmesh):
      sf_change = np.abs(sf[idx]-sf_prev[idx])/sf_prev[idx]
      error2 = max(sf_change,error2) 
    errors.append(error1)
    
    if show_iter:
      print(f"iter {iter:03d}:  Keff:{Keff:.5f}   lambda_err: {error1:.3e}   fission_err: {error2:.3e}")
    iter += 1

  # Normalize flux
  scale = max(phi[0,:])
  phi[:,0] = phi[:,0]/scale
  phi[:,1] = phi[:,1]/scale

  return errors

# %% [markdown]
# ## Sn Method

# %%
def Sn_driver():

  global geom, phi, lamb, lamb_prev, \
          iter, iter_max, nmesh, curns, Keff, wiel, psi, psid, \
          sf, ss, sf_prev, Am, src, curns_array

  mu, w = roots_legendre(norder)
  Plm = np.zeros([norder+1, norder])
  for l in range(norder+1):
    Plm[l] = eval_legendre(l,mu)

  # Prepare self-scattering data
  scat_gg = np.zeros([nmesh, ng])
  for idx in range(nmesh):
    for ig in range(ng):
      scat_gg[idx][ig] = xs[idx][tr][ig] - (xs[idx][scat][ig] + xs[idx][ab][ig])

  # Calculate Scalar Flux (phi_lgi)
  for l in range(1):
    for idx in range(nmesh):
      for ig in range(ng):
        #scal_flux[idx][ig][l] = 0.0
        #for m in range(norder):
        scal_flux[idx][ig][l] = phi[idx][ig]
    
  # Calculate Source Terms (S_fi)
  sfdx = 0
  for idx in range(nmesh):
    sn_sf[idx] = 0.0
    for ig in range(ng):
      sn_sf[idx] += xs[idx][nf][ig]*scal_flux[idx][ig][0]
    sfdx += sn_sf[idx] * geom[idx]

  for m in range(norder):
    for idx in range(nmesh):
      for ig in range(ng):
        sn_ss[idx][ig][m] = 0.0
        for g in range(ng):
          for l in range(1):
            if ig != g:
              sn_ss[idx][ig][m] += (2*l+1) * 0.5 *scal_flux[idx][g][l]*Plm[l][m]*xs[idx][scat][g]
            else:
              sn_ss[idx][ig][m] += (2*l+1) * 0.5 *scal_flux[idx][ig][l]*Plm[l][m]*scat_gg[idx][ig]
        sn_source[idx][ig][m] = sn_ss[idx][ig][m] + lamb*Chi[idx][ig]*sn_sf[idx] * 0.5

  # Set Sn Linear System and Solve Surface Angular Flux for Interior
  for m in range(norder//2):
    pm = norder-m-1
    for ig in range(ng):
      #solve for m angle
      surf_ang_flux[nmesh][ig][m] = beta_r*surf_ang_flux[nmesh][ig][pm]
      for idx in range(nmesh-1,-1,-1):
        surf_ang_flux[idx][ig][m] = (geom[idx] * sn_source[idx][ig][m] - \
        (geom[idx]/2 * xs[idx][tr][ig] + mu[m]) * surf_ang_flux[idx+1][ig][m])/ \
        (geom[idx]/2 * xs[idx][tr][ig] - mu[m])
      #solve for pm angle
      surf_ang_flux[0][ig][pm] = beta_l*surf_ang_flux[0][ig][m]
      for idx in range(1,nmesh+1):
        surf_ang_flux[idx][ig][pm] = (geom[idx-1] * sn_source[idx-1][ig][pm] - \
        (geom[idx-1]/2* xs[idx-1][tr][ig] - mu[pm]) * surf_ang_flux[idx-1][ig][pm])/ \
        (geom[idx-1]/2* xs[idx-1][tr][ig] + mu[pm])

      # Evaluate interior angular flux
        for idx in range(nmesh):
          ang_flux[idx][ig][m] = 0.5 * (surf_ang_flux[idx][ig][m] + surf_ang_flux[idx+1][ig][m])
          ang_flux[idx][ig][pm] = 0.5 * (surf_ang_flux[idx][ig][pm] + surf_ang_flux[idx+1][ig][pm])

  # Evaluate scalar flux (zeroth moment)
  for idx in range(nmesh):
    for ig in range(ng):
      phi[idx][ig] = 0.0
      for m in range(norder):
        phi[idx][ig] += w[m]*ang_flux[idx][ig][m]

  #plt.plot(surf_ang_flux[:,0,0])
  #plt.plot(surf_ang_flux[:,1,0])
  #plt.plot(surf_ang_flux[:,0,1])
  #plt.plot(surf_ang_flux[:,1,1])
  #plt.legend(["surf_ang_flux1m0","surf_ang_flux2m0","surf_ang_flux1m1","surf_ang_flux2m1"])
  #plt.show()

  # Evaluate current and D-hat
  curns_array = np.zeros([nmesh+1,ng])
  for idx in range(nmesh+1):
    for ig in range(ng):
      curns_array[idx][ig] = 0.0
      for m in range(norder):
        curns_array[idx][ig] += w[m]*mu[m]*surf_ang_flux[idx][ig][m]
      
      if idx==0:
        if BC[0] > 0:
          num = curns_array[idx][ig] - Dtilda[idx][ig]*(0 - phi[idx][ig])
          denom = 0 + phi[idx][ig]
          D_hat[idx][ig] = num/denom
        else:
          D_hat[idx][ig] = 0
      elif idx==nmesh:
        if BC[1] > 0:
          num = curns_array[idx][ig] - Dtilda[idx][ig]*(phi[idx-1][ig] - 0)
          denom = phi[idx-1][ig] + 0
          D_hat[idx][ig] = num/denom 
        else:
          D_hat[idx][ig] = 0     
      else:
        num = curns_array[idx][ig] - Dtilda[idx][ig]*(phi[idx-1][ig] - phi[idx][ig])
        denom = phi[idx-1][ig] + phi[idx][ig]
        D_hat[idx][ig] = num/denom

      #print("D_hat idx ig",idx,ig,D_hat[idx][ig])
  #plt.plot(curns_array[:,0])
  #plt.plot(curns_array[:,1])
  #plt.legend(["curns1","curns2"])
  #plt.plot(D_hat[:,0])
  #plt.plot(D_hat[:,1])
  #plt.legend(["D_hat1","D_hat2"])
  #plt.show()
          

  return

# %% [markdown]
# ## Sn Stand alone

# %%
def Sn_standalone():

  global geom, phi, lamb, lamb_prev, \
          iter, iter_max, nmesh, curns, Keff, wiel, psi, psid, sf, ss, sf_prev, Am, src
  print("beta_l: " + str(beta_l) + " beta_r: " + str(beta_r))
  print("initial lamb: " + str(lamb) + "  |   inital keff: " + str(Keff))

  # Initialize error and tolerance
  tol1 = 1E-7
  tol2 = 1E-5
  error1 = np.abs(lamb-lamb_prev)/lamb_prev
  error2 = 0.0
  for idx in range(nmesh):
    sf_change = np.abs(sf[idx] - sf_prev[idx])/sf_prev[idx]
    error2 = max(sf_change,error2)
  
  mu, w = roots_legendre(norder)
  Plm = np.zeros([norder+1, norder])
  for l in range(norder+1):
    Plm[l] = eval_legendre(l,mu)

  # Prepare self-scattering data
  scat_gg = np.zeros([nmesh, ng])
  for idx in range(nmesh):
    for ig in range(ng):
      scat_gg[idx][ig] = xs[idx][tr][ig] - (xs[idx][scat][ig] + xs[idx][ab][ig])

  # Start outer iteration
  errors = []
  while (error1>tol1):
    if iter >= iter_max:
      print("WARNING: Iteration finished without convergence")
      break
    # Calculate Scalar Flux (phi_lgi)
    for l in range(norder+1):
      for idx in range(nmesh):
        for ig in range(ng):
          scal_flux[idx][ig][l] = 0.0
          for m in range(norder):
            scal_flux[idx][ig][l] += w[m]*ang_flux[idx][ig][m]*Plm[l][m]
    
    # Calculate Source Terms (S_fi)
    sfdx = 0
    for idx in range(nmesh):
      sn_sf[idx] = 0.0
      for ig in range(ng):
        sn_sf[idx] += xs[idx][nf][ig]*scal_flux[idx][ig][0]
      sfdx += sn_sf[idx] * geom[idx]

    for m in range(norder):
      for idx in range(nmesh):
        for ig in range(ng):
          sn_ss[idx][ig][m] = 0.0
          for g in range(ng):
            for l in range(1):
              if ig != g:
                sn_ss[idx][ig][m] += (2*l+1) * 0.5 *scal_flux[idx][g][l]*Plm[l][m]*xs[idx][scat][g]
              else:
                sn_ss[idx][ig][m] += (2*l+1) * 0.5 *scal_flux[idx][ig][l]*Plm[l][m]*scat_gg[idx][ig]
          sn_source[idx][ig][m] = sn_ss[idx][ig][m] + lamb*Chi[idx][ig]*sn_sf[idx] * 0.5

    # Set Sn Linear System and Solve Surface Angular Flux for Interior
    for m in range(norder//2):
      pm = norder-m-1
      for ig in range(ng):
        #solve for m angle
        surf_ang_flux[nmesh][ig][m] = beta_r*surf_ang_flux[nmesh][ig][pm]
        for idx in range(nmesh-1,-1,-1):
          surf_ang_flux[idx][ig][m] = (geom[idx] * sn_source[idx][ig][m] - \
          (geom[idx]/2 * xs[idx][tr][ig] + mu[m]) * surf_ang_flux[idx+1][ig][m])/ \
          (geom[idx]/2 * xs[idx][tr][ig] - mu[m])
        #solve for pm angle
        surf_ang_flux[0][ig][pm] = beta_l*surf_ang_flux[0][ig][m]
        for idx in range(1,nmesh+1):
          surf_ang_flux[idx][ig][pm] = (geom[idx-1] * sn_source[idx-1][ig][pm] - \
          (geom[idx-1]/2* xs[idx-1][tr][ig] - mu[pm]) * surf_ang_flux[idx-1][ig][pm])/ \
          (geom[idx-1]/2* xs[idx-1][tr][ig] + mu[pm])
        

        # Evaluate interior angular flux
        for idx in range(nmesh):
          ang_flux[idx][ig][m] = 0.5 * (surf_ang_flux[idx][ig][m] + surf_ang_flux[idx+1][ig][m])
          ang_flux[idx][ig][pm] = 0.5 * (surf_ang_flux[idx][ig][pm] + surf_ang_flux[idx+1][ig][pm])

    # Evaluate scalar flux (zeroth moment)
    Curn_Sn = np.zeros([nmesh+1, ng])
    for idx in range(nmesh):
      for ig in range(ng):
        phi[idx][ig] = 0.0
        for m in range(norder):
          phi[idx][ig] += w[m]*ang_flux[idx][ig][m]

    for idx in range(nmesh+1):
      for ig in range(ng):
       summ = 0.0
       for m in range(norder):
         summ = summ + w[m]*mu[m]*surf_ang_flux[idx][ig][m]
       Curn_Sn[idx][ig] = summ
    
    plt.plot(Curn_Sn[:,0])
    plt.plot(Curn_Sn[:,1])
    plt.legend(["sn_curns1","sn_curns2"])
    plt.show()

    # Update sources
    sf_prev = sf.copy()
    sfdxo = sfdx
    sfdx = 0
    for idx in range(nmesh):
      sn_sf[idx] = 0
      for g in range(ng):
        sn_sf[idx] += phi[idx][g] * xs[idx][nf][g]   # fission source
      sfdx = sfdx + sn_sf[idx] * geom[idx]
    
    # Update eigenvalue
    lamb_prev = lamb
    lamb = lamb_prev * sfdxo / sfdx
    Keff = 1 / lamb

    # Update error
    error1 = np.abs(lamb - lamb_prev)/lamb_prev
    error2 = 0.0
    for idx in range(nmesh):
      sf_change = np.abs(sf[idx]-sf_prev[idx])/sf_prev[idx]
      error2 = max(sf_change,error2) 
    errors.append(error1)
    
    if show_iter:
      print(f"iter {iter:03d}:  lamb: {lamb:.5f}  Keff:{Keff:.5f}   lambda_err: {error1:.3e}   fission_err: {error2:.3e}")
    iter += 1
  
  # Normalize flux
  scale = max(phi[0,:])
  phi[:,0] = phi[:,0]/scale
  phi[:,1] = phi[:,1]/scale   


  return

# %% [markdown]
# ## P3 (Pn method)

# %% [markdown]
# #P3 stand alone

# %%
def SetLS0():
  '''
  Sets up linear system for phi0.
  '''
  global xs, geom, nmesh, A1, A2, A12, A21, Dtilda, sf, ss, lamb, Am, src, \
          phi, phi2
  
  for idx in range(nmesh):
    xst1 = xs[idx][ab][0] + xs[idx][scat][0]
    xst2 = xs[idx][ab][1] + xs[idx][scat][1]
    
    A1[idx][idx] = Dtilda[idx][0] + Dtilda[idx+1][0] + geom[idx]*xst1
    A2[idx][idx] = Dtilda[idx][1] + Dtilda[idx+1][1] + geom[idx]*xst2
    A12[idx][idx] = 0.0
    A21[idx][idx] = 0.0

    # left BC  
    if idx == 0: 
      A1[idx][idx+1] = -Dtilda[idx+1][0]
      A2[idx][idx+1] = -Dtilda[idx+1][1]
    
    # right BC
    elif idx == nmesh-1:
      A1[idx][idx-1] = -Dtilda[idx][0]
      A2[idx][idx-1] = -Dtilda[idx][1]
    
    # interior
    else:
      A1[idx][idx-1] = -Dtilda[idx][0]
      A2[idx][idx-1] = -Dtilda[idx][1]
      A1[idx][idx+1] = -Dtilda[idx+1][0]
      A2[idx][idx+1] = -Dtilda[idx+1][1]
    
    ss1=phi[idx][0] * xs[idx][scat][0]
    ss2=phi[idx][1] * xs[idx][scat][1]
    b1[idx]  = (ss2 + Chi[idx,0]*sf[idx]*lamb + 2*xst1*phi2[idx][0]) * geom[idx]
    b2[idx]  = (ss1 + Chi[idx,1]*sf[idx]*lamb + 2*xst2*phi2[idx][1]) * geom[idx]

  Am = np.vstack([np.hstack([A1, A21]), np.hstack([A12, A2])])
  src = np.hstack([b1,b2])

  return

# %%
def SetLS2():
  '''
  Sets up linear system for phi2.
  '''
  global xs, geom, nmesh, A1, A2, A12, A21, Dtilda, lamb, Am_m2, \
          b1_m2, b2_m2, src_m2, phim0
  
  for idx in range(nmesh):
    xst1 = xs[idx][ab][0] + xs[idx][scat][0]
    xst2 = xs[idx][ab][1] + xs[idx][scat][1]
    
    A1[idx][idx] = 9/7*Dtilda[idx][0] + 9/7*Dtilda[idx+1][0] + 3*geom[idx]*xst1
    A2[idx][idx] = 9/7*Dtilda[idx][1] + 9/7*Dtilda[idx+1][1] + 3*geom[idx]*xst2
    A12[idx][idx] = 0.0
    A21[idx][idx] = 0.0

    # left BC  
    if idx == 0: 
      A1[idx][idx+1] = -9/7*Dtilda[idx+1][0]
      A2[idx][idx+1] = -9/7*Dtilda[idx+1][1]
    
    # right BC
    elif idx == nmesh-1:
      A1[idx][idx-1] = -9/7*Dtilda[idx][0]
      A2[idx][idx-1] = -9/7*Dtilda[idx][1]
    
    # interior
    else:
      A1[idx][idx-1] = -9/7*Dtilda[idx][0]
      A2[idx][idx-1] = -9/7*Dtilda[idx][1]
      A1[idx][idx+1] = -9/7*Dtilda[idx+1][0]
      A2[idx][idx+1] = -9/7*Dtilda[idx+1][1]
    
    ss1=phi[idx][0] * xs[idx][scat][0]
    ss2=phi[idx][1] * xs[idx][scat][1]
    b1_m2[idx] = -2/3*(ss2 + Chi[idx,0]*sf[idx]*lamb - xst1*phim0[idx][0]) * geom[idx]
    b2_m2[idx] = -2/3*(ss1 + Chi[idx,1]*sf[idx]*lamb - xst2*phim0[idx][1]) * geom[idx]
  
  Am_m2 = np.vstack([np.hstack([A1, A21]), np.hstack([A12, A2])])
  src_m2 = np.hstack([b1_m2,b2_m2])

  return

# %%
def Pn_standalone():
  '''
  FDM method with SP3. No CMFD yet.
  '''
  global geom, phi, lamb, lamb_prev, Dtilda, D_hat, D2tilda, A1, A2, A12, A21, \
          b1, b2, iter, iter_max, nmesh, curns, Keff, wiel, psi, psid, sf, ss, \
          sf_prev, Am, src, Am_m2, src_m2, bcval

  # Initialize error and tolerance
  tol1 = 1E-7
  tol2 = 1E-5
  error1 = np.abs(lamb-lamb_prev)/lamb_prev
  error2 = 0.0
  for idx in range(nmesh):
    sf_change = np.abs(sf[idx] - sf_prev[idx])/sf_prev[idx]
    error2 = max(sf_change,error2)

  # Diffusion Coefficients
  #for idx in range(nmesh):  
  #  Dc[idx] = 1/3*np.reciprocal(xs[idx][tr])

  # Initialze D_tilda
  for idx in range(nmesh+1):
    for g in range(ng):
      if idx==0:
        if bcval[0] == 0:
          Dtilda[idx][g] = 0
        else:
          Dtilda[idx][g] = 1/(1/bcval[0] + geom[0]/(2*Dc[0][g]))
      elif idx==nmesh:
        if bcval[1] == 0:
          Dtilda[idx][g] = 0
        else:
          Dtilda[idx][g] = 1/(1/bcval[1] + geom[nmesh-1]/(2*Dc[nmesh-1][g]))
      else: 
        Dtilda[idx][g] = 1/(geom[idx-1]/(2*Dc[idx-1][g]) + geom[idx]/(2*Dc[idx][g]))
  
  # Start outer iteration
  errors = []
  while (error1>tol1 or error2>tol2):
    if iter >= iter_max:
      print("WARNING: Iteration finished without convergence")
      break
    
    # Run NEM driver (instead update current directly)
    # NEM_driver()
    # for g in range(ng):
      # curns2[idx][g] = -Dc[idx][g] * (phi[idx][g] + 2*phi2[idx][g])
    
    # Apply BC for surface fluxes
    # for idx in range(nmesh+1):
    #   for g in range(ng): 
    #       phi1s[idx][g][0] = alpha*phim0s[idx][g]
    #       phi3s[idx][g][0] = 9/7*alpha*phi2s[idx][g]

    # Update D2tilda
    # for idx in range(nmesh+1):
    #   for g in range(ng): 
    #       D2tilda[idx][g][0] = Dtilda[idx][g] - D_hat[idx][g] # left
    #       D2tilda[idx][g][1] = Dtilda[idx][g] + D_hat[idx][g] # right

    # Sets 0th moment linear system
    SetLS0()

    # Wielandt shift
    # if wiel:
    #   Wiel()

    # Solve
    sol = np.linalg.solve(Am, src)
    phim0[:,0] = sol[:nmesh]
    phim0[:,1] = sol[nmesh:]

    # Sets 2nd moment linear system
    SetLS2()

    # Wielandt shift
    # if wiel:
    #   Wiel()

    # Solve
    sol = np.linalg.solve(Am_m2, src_m2)
    phi2[:,0] = sol[:nmesh]
    phi2[:,1] = sol[nmesh:]

    # Update flux
    for idx in range(nmesh):
      for g in range(ng):
        phi[idx][g] = phim0[idx][g] - 2*phi2[idx][g]
    
    # Update sources
    sf_prev = sf.copy()
    sf,ss = np.zeros([nmesh]),np.zeros([nmesh])
    for idx in range(nmesh):
      for g in range(ng):
        sf[idx] += phi[idx][g] * xs[idx][nf][g]   # fission source
        # ss[idx] += phi[idx][g] * xs[idx][scat][g] # scattering source
      # psi[idx] = sf[idx] * geom[idx]
    
    # Update eigenvalue
    UpdateEigen()

    # Update error
    error1 = np.abs(lamb-lamb_prev)/lamb_prev
    error2 = 0.0
    for idx in range(nmesh):
      sf_change = np.abs(sf[idx]-sf_prev[idx])/sf_prev[idx]
      error2 = max(sf_change,error2) 
    errors.append(error1)
    
    if show_iter:
      print(f"iter {iter:03d}:  Keff:{Keff:.5f}   lambda_err: {error1:.3e}   fission_err: {error2:.3e}")
    iter += 1

  # Normalize flux
  Normalize()

  return errors

# %% [markdown]
# # P3 Driver

# %%
def Pn_driver():
  
  global geom, phi, lamb, lamb_prev, Dtilda, D_hat, D2tilda, A1, A2, A12, A21, \
          b1, b2, iter, iter_max, nmesh, curns, Keff, wiel, psi, psid, sf, ss, \
          sf_prev, Am, src, Am_m2, src_m2, bcval

  # Update sources
  sf_prev = sf.copy()
  sf,ss = np.zeros([nmesh]),np.zeros([nmesh])
  for idx in range(nmesh):
    for g in range(ng):
      sf[idx] += phi[idx][g] * xs[idx][nf][g]   # fission source
  
  # Set and solve linear system    
  SetLS0()
    
  # Solve
  sol = np.linalg.solve(Am, src)
  phim0[:,0] = sol[:nmesh]
  phim0[:,1] = sol[nmesh:]
    
  # Sets 2nd moment linear system
  SetLS2()

  # Solve
  sol = np.linalg.solve(Am_m2, src_m2)
  phi2[:,0] = sol[:nmesh]
  phi2[:,1] = sol[nmesh:]
  
  #find phi0, aka phi
  for idx in range(nmesh):
    for g in range(ng):
      phi[idx][g] = phim0[idx][g] - 2 * phi2[idx][g]
    
  # Evaluate current and update D-hat
  curns_array = np.zeros([nmesh+1,ng])
  for idx in range(nmesh+1):
    for ig in range(ng):
      if idx == 0:
        if BC[0] > 0:
          curns_array[idx][ig] = -Dc[idx][ig]*(0 - phim0[idx][ig])/geom[idx]
          num = curns_array[idx][ig] - Dtilda[idx][ig]*(0 - phi[idx][ig])
          denom = 0 + phi[idx][ig]
          D_hat[idx][ig] = num/denom
        else:
          D_hat[idx][ig] = 0
      
      elif idx == nmesh:
        if BC[1] > 0:
          curns_array[idx,ig] = -Dc[idx][ig]*(phim0[idx-1][ig] - 0)/geom[idx-1]
          num = curns_array[idx][ig] - Dtilda[idx][ig]*(phi[idx-1][ig] - 0)
          denom = phi[idx-1][ig] + 0
          D_hat[idx][ig] = num/denom 
        else:
          D_hat[idx][ig] = 0
      
      else:
        curns_array[idx][ig] = Dc[idx][ig]*(phim0[idx-1][ig] - phim0[idx][ig])/geom[idx-1]
        num = curns_array[idx][ig] - Dtilda[idx][ig]*(phi[idx-1][ig] - phi[idx][ig])
        denom = phi[idx-1][ig] + phi[idx][ig]
        D_hat[idx][ig] = num/denom
    
  return

# %% [markdown]
# ## Plot and Print Results

# %%
def plot_flux(pphi, nmesh, length, plot_type, phi_a, log=False, C=0):
  '''
  Plots flux distribution.
  '''
  global ng

  if plot_type == 'Analytical':
    num = len(pphi)
    nodes = np.linspace(0, 100, num)
  else:
    nodes = [float((i+1/2)*length) for i in range(nmesh)]

  colors = ('blue', 'red')
  for g in range(ng):
    plt.plot(nodes,(pphi[:,g]),label=f'Group {g+1}', color=colors[g])
  
  #plt.xticks([float(i*length) for i in range(nmesh+1)])
  plt.xlabel("x (cm)")
  plt.ylabel(r'$\phi$')
  if log:
    plt.yscale("linear")
  if plot_type == 'Analytical':
    plt.title(f"{plot_type} flux with C10 = 1 / C20 = {C:.06e}")
  else:
    plt.title(f"{plot_type} flux with {nmesh} meshes of length {length} cm")
  
  plt.legend()

  #plt.show()

  return

# %%
def plot_flux_diff(phi, nmesh, nregions, nmesh_pr, phi_a, log_plot):
  '''
  Prints and plots the flux differences between numerical and analytical
  '''
  phi_num_avg = []
  phi_ana_avg = []
  lenA = int((len(phi_a)-1)/nregions)
  lenA_mesh = int((len(phi_a)-1)/nmesh)
  phi1_error = []
  phi2_error = []
  
  # Print errors
  print("Error between numerical and analytical solution per region:")
  for idx in range(nregions):
    val1 = sum(phi[slice(idx*nmesh_pr,(idx+1)*nmesh_pr)])/nmesh_pr
    phi_num_avg.append(val1)

    val2 = sum(phi_a[slice(idx*lenA,(idx+1)*lenA)])/lenA
    phi_ana_avg.append(val2)
    print(f"{idx+1}: {abs(val2 - val1)/val2}")

  # TODO: plot errors
  for imesh in range(nmesh):
    iA = int(np.rint((2*imesh+1)/2*len(phi_a)/nmesh))
    phi_ana = sum(phi_a[slice(imesh*lenA_mesh,(imesh+1)*lenA_mesh)])/lenA_mesh
    phi1_error.append(np.abs(1-phi[imesh][0]/phi_ana[0])*100)
    phi2_error.append(np.abs(1-phi[imesh][1]/phi_ana[1])*100)
  meshes = np.linspace(0.0,100.0,num=nmesh) 
  plt.plot(meshes,phi1_error)
  plt.plot(meshes,phi2_error)
  plt.ylabel("Flux Error(%)")
  plt.xlabel("Length (cm)")
  plt.legend(["Group 1","Group 2"])
  plt.show()
  
  return

# %% [markdown]
# # Testing

# %%
# Run the finite difference calculation
print("############ Run CMFD alone ##################")
Solver = 0 #run cmfd without sn
CMFD()
phicmfd = phi.copy();
keff_cmfd = 1/lamb

print("############ Run CMFD-Sn solver ##################")
lamb=lam_init
Keff=1/lamb
iter = 0
Solver = 1  #run cmfd with sn
CMFD()
phisn = phi.copy();
keff_sn = 1/lamb

print("############ Run CMFD-Pn solver ##################")
lamb=lam_init
Keff=1/lamb
iter = 0
Solver = 2  #run cmfd with pn
CMFD()
phipn = phi.copy();
keff_pn = 1/lamb

plt.plot(phicmfd[:,0])
plt.plot(phicmfd[:,1])
plt.plot(phisn[:,0])
plt.plot(phisn[:,1])
plt.plot(phipn[:,0])
plt.plot(phipn[:,1])
plt.legend(["CMFD1","CMFD2","Sn1","Sn2","Pn1","Pn2"])

print("######################################################################")
print("cmfd-alone keff:", keff_cmfd)
print("cmfd-sn keff:", keff_sn, "keff diff (pcm): ", (keff_sn-keff_cmfd)*1e5)
print("cmfd-pn keff:", keff_pn, "keff diff (pcm): ", (keff_pn-keff_cmfd)*1e5)
print("######################################################################")

# Plot Flux differences
# plot_flux_diff(phi1, nmesh, nregions, nmesh_per_region, phi2, log_plot)

# K-eff error
#print(f"\nCMFD k-eff for {materials[0]}: {Keff:.08f}")
#print(f"Analytical  k-eff for {materials[0]}: {keff_a:.08f} " \
#      f"(C10 = {C10}, C20 = {C20})")
#print(f"Error (pcm): {1e5*(Keff-keff_a)/keff_a:.06f}")
# Out:
# ############ Run CMFD alone ##################
# iter 000:  Keff:1.10446   lambda_err: 9.458e-02   fission_err: 8.550e-01
# iter 001:  Keff:1.18379   lambda_err: 6.702e-02   fission_err: 3.590e-01
# iter 002:  Keff:1.20533   lambda_err: 1.786e-02   fission_err: 1.773e-01
# iter 003:  Keff:1.21212   lambda_err: 5.607e-03   fission_err: 9.798e-02
# iter 004:  Keff:1.21518   lambda_err: 2.514e-03   fission_err: 5.922e-02
# iter 005:  Keff:1.21670   lambda_err: 1.252e-03   fission_err: 3.817e-02
# iter 006:  Keff:1.21754   lambda_err: 6.854e-04   fission_err: 2.603e-02
# iter 007:  Keff:1.21803   lambda_err: 4.041e-04   fission_err: 1.857e-02
# iter 008:  Keff:1.21833   lambda_err: 2.507e-04   fission_err: 1.371e-02
# iter 009:  Keff:1.21853   lambda_err: 1.613e-04   fission_err: 1.037e-02
# iter 010:  Keff:1.21866   lambda_err: 1.067e-04   fission_err: 7.981e-03
# iter 011:  Keff:1.21875   lambda_err: 7.236e-05   fission_err: 6.217e-03
# iter 012:  Keff:1.21881   lambda_err: 5.013e-05   fission_err: 4.882e-03
# iter 013:  Keff:1.21885   lambda_err: 3.542e-05   fission_err: 3.855e-03
# iter 014:  Keff:1.21888   lambda_err: 2.547e-05   fission_err: 3.056e-03
# iter 015:  Keff:1.21891   lambda_err: 1.862e-05   fission_err: 2.429e-03
# iter 016:  Keff:1.21892   lambda_err: 1.380e-05   fission_err: 1.935e-03
# iter 017:  Keff:1.21894   lambda_err: 1.036e-05   fission_err: 1.543e-03
# iter 018:  Keff:1.21895   lambda_err: 7.858e-06   fission_err: 1.231e-03
# iter 019:  Keff:1.21895   lambda_err: 6.017e-06   fission_err: 9.835e-04
# iter 020:  Keff:1.21896   lambda_err: 4.643e-06   fission_err: 7.860e-04
# iter 021:  Keff:1.21896   lambda_err: 3.607e-06   fission_err: 6.284e-04
# iter 022:  Keff:1.21897   lambda_err: 2.818e-06   fission_err: 5.026e-04
# iter 023:  Keff:1.21897   lambda_err: 2.211e-06   fission_err: 4.020e-04
# iter 024:  Keff:1.21897   lambda_err: 1.742e-06   fission_err: 3.216e-04
# iter 025:  Keff:1.21897   lambda_err: 1.376e-06   fission_err: 2.573e-04
# iter 026:  Keff:1.21898   lambda_err: 1.090e-06   fission_err: 2.059e-04
# iter 027:  Keff:1.21898   lambda_err: 8.655e-07   fission_err: 1.648e-04
# iter 028:  Keff:1.21898   lambda_err: 6.882e-07   fission_err: 1.319e-04
# iter 029:  Keff:1.21898   lambda_err: 5.479e-07   fission_err: 1.056e-04
# iter 030:  Keff:1.21898   lambda_err: 4.367e-07   fission_err: 8.452e-05
# iter 031:  Keff:1.21898   lambda_err: 3.484e-07   fission_err: 6.765e-05
# iter 032:  Keff:1.21898   lambda_err: 2.781e-07   fission_err: 5.416e-05
# iter 033:  Keff:1.21898   lambda_err: 2.221e-07   fission_err: 4.335e-05
# iter 034:  Keff:1.21898   lambda_err: 1.775e-07   fission_err: 3.471e-05
# iter 035:  Keff:1.21898   lambda_err: 1.419e-07   fission_err: 2.778e-05
# iter 036:  Keff:1.21898   lambda_err: 1.135e-07   fission_err: 2.224e-05
# iter 037:  Keff:1.21898   lambda_err: 9.075e-08   fission_err: 1.781e-05
# ############ Run CMFD-Sn solver ##################
# iter 000:  Keff:1.21452   lambda_err: 1.766e-01   fission_err: 4.588e-01
# iter 001:  Keff:1.21922   lambda_err: 3.853e-03   fission_err: 4.587e-01
# iter 002:  Keff:1.21957   lambda_err: 2.933e-04   fission_err: 2.379e-01
# iter 003:  Keff:1.21906   lambda_err: 4.222e-04   fission_err: 1.007e-01
# iter 004:  Keff:1.21911   lambda_err: 4.152e-05   fission_err: 5.481e-02
# iter 005:  Keff:1.21902   lambda_err: 7.198e-05   fission_err: 2.927e-02
# iter 006:  Keff:1.21904   lambda_err: 1.535e-05   fission_err: 1.584e-02
# iter 007:  Keff:1.21902   lambda_err: 1.406e-05   fission_err: 8.523e-03
# iter 008:  Keff:1.21903   lambda_err: 4.150e-06   fission_err: 4.704e-03
# iter 009:  Keff:1.21903   lambda_err: 3.165e-06   fission_err: 2.498e-03
# iter 010:  Keff:1.21903   lambda_err: 9.981e-07   fission_err: 1.402e-03
# iter 011:  Keff:1.21903   lambda_err: 7.898e-07   fission_err: 7.324e-04
# iter 012:  Keff:1.21903   lambda_err: 2.157e-07   fission_err: 4.219e-04
# iter 013:  Keff:1.21903   lambda_err: 2.189e-07   fission_err: 2.131e-04
# iter 014:  Keff:1.21903   lambda_err: 3.378e-08   fission_err: 1.291e-04
# ############ Run CMFD-Pn solver ##################
# iter 000:  Keff:1.20928   lambda_err: 1.731e-01   fission_err: 1.641e+01
# iter 001:  Keff:1.21598   lambda_err: 5.517e-03   fission_err: 4.865e-02
# iter 002:  Keff:1.21763   lambda_err: 1.351e-03   fission_err: 1.027e-02
# iter 003:  Keff:1.21809   lambda_err: 3.787e-04   fission_err: 4.210e-03
# iter 004:  Keff:1.21826   lambda_err: 1.405e-04   fission_err: 1.974e-03
# iter 005:  Keff:1.21834   lambda_err: 6.109e-05   fission_err: 9.757e-04
# iter 006:  Keff:1.21837   lambda_err: 2.721e-05   fission_err: 5.039e-04
# iter 007:  Keff:1.21838   lambda_err: 1.190e-05   fission_err: 2.814e-04
# iter 008:  Keff:1.21839   lambda_err: 5.067e-06   fission_err: 1.753e-04
# iter 009:  Keff:1.21839   lambda_err: 2.090e-06   fission_err: 1.308e-04
# iter 010:  Keff:1.21839   lambda_err: 8.242e-07   fission_err: 1.127e-04
# iter 011:  Keff:1.21839   lambda_err: 3.014e-07   fission_err: 9.989e-05
# iter 012:  Keff:1.21839   lambda_err: 9.377e-08   fission_err: 9.036e-05
# ######################################################################
# cmfd-alone keff: 1.2189800668587678
# cmfd-sn keff: 1.2190259391049811 keff diff (pcm):  4.587224621332986
# cmfd-pn keff: 1.2183948110585445 keff diff (pcm):  -58.52558002232833
# ######################################################################
