# %% [markdown]
# <a href="https://colab.research.google.com/github/sjtao98/NUCL610/blob/main/Project3/Project3_NUCL610.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROJECT 3 - NUCL 610
# # Sn Method and Pn Method

# %% [markdown]
# ## Preparation and Initialization

# %%
import math as m
import cmath as cm
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
from scipy.special import roots_legendre, eval_legendre

# %%
# Global variables to be accessed anywhere
global ng, nregions, geom_length, nmesh_per_region, materials, \
        XS_num, nmesh, geom, xs, BC, \
        s0, s1, s2, curns, phi, adfs, Chi, l, r, ab, tr, nf, scat, even_moments, \
        nx, ny, Dtilda, D_hat, D2tilda, A1, A2, A12, A21, b1, b2, Dc, Keff, iter, iter_max, \
        lamb, lamb_prev, eshift, eshift0, eshift_r, wiel, lamb_s, \
        psi, psid, sf_prev, Am, src,\
        ang_flux

################################################################
#                         Data Input                           #
# ------------------------------------------------------------ #
# ng = number of energy groups                                 #
# nregions = Number of total regions in geometry               #
# materials = List of materials with a length of nmesh         #
# nmesh_per_reg = Number of refined meshes per material region #
# nmesh = Number of total meshes in geometry                   #
# BC = Boundary conditions (0=refl, 1=zero flux, 2=vacuum)     #
################################################################

ng = 2
nregions = 5
geom_length = 100
nmesh_per_region = 16
norder = 8 # For Sn method
#materials  = ['UO2']*nregions
#materials  = ['MOX']*nregions
materials  = ['UO2','MOX','UO2','MOX','UO2']
lam_init = 1
wiel = True
show_iter = True
log_plot = True

alpha = 0.5
BC = [0,0] #0: reflective, 2: vacuum
beta_l = 1.0 # left albedo
beta_r = 1.0 # right albedo

data = [[8.873837e-3,	5.424022e-3,	2.332139e-1,	1.592122e-2],
        [6.377025e-2,	9.959442e-2,	8.918111e-1,	0],
        [1.406811e-2, 1.126274e-2,	2.219159e-1,	1.147102e-2],
        [2.691350e-1, 4.577393e-1,	1.043375e+0,	0]]

#solver on and off, 1: Sn, 2 : Pn, else: cmfd-alone
Solver = 1

# Assign enum to XS names
ab   = 0
nf   = 1
tr   = 2
scat = 3
XS_num = 4

# Process input
nmesh = nregions * nmesh_per_region
lmesh = geom_length / nmesh
geom = [lmesh]*nmesh
xs = np.zeros([nmesh, XS_num, ng])
mat_xs = {'UO2':{0:{}, 1:{}, 2:{}, 3:{}}, 'MOX':{0:{}, 1:{}, 2:{}, 3:{}}}

# Initialize matrices
curns   = np.zeros([nmesh,ng])
curns2  = np.zeros([nmesh,ng])

phi     = np.ones([nmesh,ng])
phim0   = np.ones([nmesh,ng]) # phi modified 0 = phi0 + 2*phi2
phi1    = np.ones([nmesh,ng])
phi2    = np.ones([nmesh,ng])
phi3    = np.ones([nmesh,ng])
sf      = np.ones([nmesh])
ss      = np.ones([nmesh])
sf2     = np.ones([nmesh]) # for S tilda 2
ss2     = np.ones([nmesh]) # for S tilda 2
psi     = np.zeros([nmesh])
psid    = np.zeros([nmesh])
sf_prev = np.ones([nmesh])

Dc      = np.ones([nmesh+1,ng])
D_hat   = np.zeros([nmesh+1,ng])
Dtilda  = np.zeros([nmesh+1,ng])
D2tilda = np.zeros([nmesh+1,ng,2]) # left and right

# only 1 in first group of fuel
Chi      = np.ones([nmesh,ng])
Chi[:,1] = .0

# Constants
l = 0 
r = 1
even_moments = True

# Dimensions
nx = nmesh
ny = 1

# Iterations
iter = 0
iter_max = 1000

# Wielandt
# fraction of fission source remaining on RHS after eigenvalue shift
eshift_r = 0.1
# eigenvalue error estimation factor
eshift0  = 10
eshift   = eshift_r

# redefine materials
new_materials = []
for mat in materials:
  for idx in range(nmesh_per_region):
    new_materials.append(mat)

# process xs
for idx,mat in enumerate(mat_xs.keys()):
  offset = idx*ng
  for xs_type in range(XS_num):
    for g in range(ng):
      mat_xs[mat][xs_type][g] = float(data[g+offset][xs_type])
      
# process GEOM
for idx,mat in enumerate(new_materials):
  offset = idx*ng
  for xs_type in range(XS_num):
    for g in range(ng):
      xs[idx][xs_type][g] = mat_xs[mat][xs_type][g]

# Diffusion Coefficients
for idx in range(nmesh):  
  Dc[idx] = 1/3*np.reciprocal(xs[idx][tr])

# process BC
bcval = []
for idx,bc in enumerate(BC):
  if bc == 0:
    bcval.append(0)
  elif bc > 0:
    bcval.append(alpha)
  else:
    print("Error! no negative BC allowed")

# Sources
lamb = lam_init
lamb_prev = 0.1
Keff = 1/lamb
for idx in range(nmesh):
  for g in range(ng):
    sf[idx] = sf[idx] + phi[idx][g]*xs[idx][nf][g]   # fission source
    ss[idx] = ss[idx] + phi[idx][g]*xs[idx][scat][g] # scattering source
  psi[idx] = sum(xs[idx][nf]) * geom[idx]

# P3(0)/CMFD matrix
A1  = np.zeros([nmesh,nmesh])
A2  = np.zeros([nmesh,nmesh])
A12 = np.zeros([nmesh,nmesh])
A21 = np.zeros([nmesh,nmesh])
b1  = np.zeros([nmesh])
b2  = np.zeros([nmesh])
Am  = np.vstack([np.hstack([A1, A21]), np.hstack([A12, A2])])
src = np.hstack([b1,b2])

# P3 matrix for phi2
A1_m2  = np.zeros([nmesh,nmesh])
A2_m2  = np.zeros([nmesh,nmesh])
A12_m2 = np.zeros([nmesh,nmesh])
A21_m2 = np.zeros([nmesh,nmesh])
b1_m2  = np.zeros([nmesh])
b2_m2  = np.zeros([nmesh])
Am_m2  = np.vstack([np.hstack([A1_m2, A21_m2]), np.hstack([A12_m2, A2_m2])])
src_m2 = np.hstack([b1_m2,b2_m2])

# Sn variables
ang_flux = np.ones([nmesh,ng,norder])
surf_ang_flux = np.ones([nmesh+1,ng,norder])
scal_flux = np.ones([nmesh,ng,norder+1])
sn_sf  = np.zeros([nmesh])
sn_ss  = np.zeros([nmesh,ng,norder])
sn_source  = np.zeros([nmesh,ng,norder])
curns_array = np.zeros([nmesh+1,ng])

# %% [markdown]
# ## CMFD

# %%
def UpdateEigen():
  '''
  Updates eigenvalue.
  '''
  global lamb_prev, lamb, sf, psid, psi, Keff, sf_prev, wiel

  lamb_prev = lamb
  # Multiply eigenvalue shift by <F*flux_n> / <F*flux_n+1>
  gamma_d, gamma_n = 0,0
  for idx in range(nmesh):
    psid[idx] = psi[idx]
    psi[idx]  = sf[idx] * geom[idx]
    gamma_d += psid[idx] * psid[idx]
    gamma_n += psi[idx] * psi[idx]

  if wiel:
    # new lambda is original shift + new shift
    lamb = lamb_s + (lamb_prev - lamb_s) * gamma_d/gamma_n

  else:
    # Ordinary way
    lamb = lamb_prev*gamma_d/gamma_n  #sum(sf_prev)/sum(sf)
  
  # Determine keff from lambda
  Keff = 1/lamb
  
  return

# %%
def Wiel():
  '''
  Wielandt shift to create new linear system.
  '''
  global eshift, eshift0, eshift_r, lamb, lamb_s, lamb_prev, \
          psi, ss, sf, A1, b1, A2, b2, xs, iter
  
  # Error
  eig_err = abs(lamb - lamb_prev)

  # Calculate shift
  lamb_s = eshift * max(0.3, lamb - eshift0*eig_err)
  lamb_del = lamb - lamb_s

  # Apply shift
  for idx in range(nmesh):
    A1[idx][idx]  -= sum(geom[idx] * xs[idx][nf]) * lamb_s
    fs = psi[idx] * lamb_del
    b1[idx]       = Chi[idx,0] * fs
    b2[idx]       = Chi[idx,1] * fs

  return

# %%
def SetLS():
  '''
  Sets up linear system.
  '''
  global xs, geom, nmesh, A1, A2, A12, A21, D2tilda, sf, ss, lamb, Am, src

  for idx in range(nmesh):
    xst1 = xs[idx][ab][0] + xs[idx][scat][0]
    A1[idx][idx] = geom[idx]*xst1 + D2tilda[idx][0][0] + D2tilda[idx+1][0][1]
    A2[idx][idx] = geom[idx]*xs[idx][ab][1] + D2tilda[idx][1][0] + D2tilda[idx+1][1][1]
    A12[idx][idx] = -geom[idx]*xs[idx][scat][0]
    A21[idx][idx] = 0.0

    # left BC  
    if idx==0: 
      A1[idx][idx+1] = -D2tilda[idx+1][0][0]
      A2[idx][idx+1] = -D2tilda[idx+1][1][0]
    
    # right BC
    elif idx==nmesh-1:
      A1[idx][idx-1] = -D2tilda[idx][0][1]
      A2[idx][idx-1] = -D2tilda[idx][1][1]
    
    # interior
    else:
      A1[idx][idx-1] = -D2tilda[idx][0][1]
      A2[idx][idx-1] = -D2tilda[idx][1][1]
      A1[idx][idx+1] = -D2tilda[idx+1][0][0]
      A2[idx][idx+1] = -D2tilda[idx+1][1][0] 
      
    b1[idx]  = Chi[idx,0] * psi[idx] * lamb
    b2[idx]  = Chi[idx,1] * psi[idx] * lamb

  Am = np.vstack([np.hstack([A1, A21]), np.hstack([A12, A2])])
  src = np.hstack([b1,b2])

  return

# %%
def Normalize():
  '''
  Normalize fliex
  '''
  global phi, phim0, phi1, phi2, phi3

  scale = phi[0][0]#max(phi[0,:])
  phi[:,0] = phi[:,0]/scale
  phi[:,1] = phi[:,1]/scale
  
  return

# %%
def CMFD():
  '''
  Updates flux between nodal and FDM methods 
  '''
  global geom, phi, lamb, lamb_prev, Dtilda, D_hat, D2tilda, A1, A2, A12, A21, b1, b2, \
          iter, iter_max, nmesh, curns, Keff, wiel, psi, psid, sf, ss, sf_prev, Am, src, SnON, curns_array

  # Initialize error and tolerance
  tol1 = 1E-7
  tol2 = 1E-7
  error1 = np.abs(lamb-lamb_prev)/lamb_prev
  error2 = 0.0
  for idx in range(nmesh):
    sf_change = np.abs(sf[idx] - sf_prev[idx])/sf_prev[idx]
    error2 = max(sf_change,error2)

  # Diffusion Coefficients
  #for idx in range(nmesh):  
    #Dc[idx] = 1/3*np.reciprocal(xs[idx][tr])

  for idx in range(nmesh+1):
    for g in range(ng):
      if idx==0:
        if BC[0] == 0:
          Dtilda[idx][g] = 0.0
        else:
          Dtilda[idx][g] = 1/(1/0.5 + geom[0]/2/Dc[0][g])
      elif idx==nmesh: 
        if BC[1] == 0:
          Dtilda[idx][g] = 0.0
        else:
          Dtilda[idx][g] = 1/(1/0.5 + geom[nmesh-1]/2/Dc[nmesh-1][g])
      else: 
        Dtilda[idx][g] = 1/(geom[idx-1]/2/Dc[idx-1][g] + geom[idx]/2/Dc[idx][g])
  
  # Start outer iteration
  errors = []
  while (error1>tol1):
    if iter >= iter_max:
      print("WARNING: Iteration finished without convergence")
      break
    
    # Run NEM driver
    # NEM_driver()

    # Run Sn/Pn Driver
    if Solver == 1:
      Sn_driver()
    elif Solver == 2:
      Pn_driver()

    # Update D2tilda
    for idx in range(nmesh+1):
      for g in range(ng): 
          D2tilda[idx][g][0] = Dtilda[idx][g] - D_hat[idx][g] # left
          D2tilda[idx][g][1] = Dtilda[idx][g] + D_hat[idx][g] # right
    
    # Sets linear system
    SetLS()

    # Wielandt shift
    if wiel:
      Wiel()

    # Solve linear system
    sol = np.linalg.solve(Am, src)

    phi[:,0] = sol[:nmesh]
    phi[:,1] = sol[nmesh:]


    # Calculate FD currents
    for idx in range(nmesh+1):
      for ig in range(ng):
        if idx == 0:
          curns_array[idx,ig] = D2tilda[idx][g][1]*phi[idx,ig]
        elif idx == nmesh:
          curns_array[idx,ig] = D2tilda[idx][g][0]*phi[idx-1,ig]
        else:
          curns_array[idx,ig] = D2tilda[idx][g][0]*phi[idx-1,ig] + D2tilda[idx][g][1]*phi[idx,ig]
    """
    plt.plot(curns_array[:,0])
    plt.plot(curns_array[:,1])
    plt.legend(["cmfd_curns1","cmfd_curns2"])
    plt.show()
    """
    # Update sources
    sf_prev = sf.copy()
    sf,ss = np.zeros([nmesh]),np.zeros([nmesh])
    for idx in range(nmesh):
      for g in range(ng):
        sf[idx] += phi[idx][g] * xs[idx][nf][g]   # fission source
        # ss[idx] += phi[idx][g] * xs[idx][scat][g] # scattering source
    
    # Update eigenvalue
    UpdateEigen()

    # Update error
    error1 = np.abs(lamb-lamb_prev)/lamb_prev
    error2 = 0.0
    for idx in range(nmesh):
      sf_change = np.abs(sf[idx]-sf_prev[idx])/sf_prev[idx]
      error2 = max(sf_change,error2) 
    errors.append(error1)
    
    if show_iter:
      print(f"iter {iter:03d}:  Keff:{Keff:.5f}   lambda_err: {error1:.3e}   fission_err: {error2:.3e}")
    iter += 1
    if error2 <= tol2:
      break

  # Normalize flux
  scale =phi[0][0] #max(phi[0,:])
  phi[:,0] = phi[:,0]/scale
  phi[:,1] = phi[:,1]/scale

  return errors

# %% [markdown]
# ## Sn Method

# %%
def Sn_driver():

  global geom, phi, lamb, lamb_prev, \
          iter, iter_max, nmesh, curns, Keff, wiel, psi, psid, \
          sf, ss, sf_prev, Am, src, curns_array

  mu, w = roots_legendre(norder)
  Plm = np.zeros([norder+1, norder])
  for l in range(norder+1):
    Plm[l] = eval_legendre(l,mu)

  # Prepare self-scattering data
  scat_gg = np.zeros([nmesh, ng])
  for idx in range(nmesh):
    for ig in range(ng):
      scat_gg[idx][ig] = xs[idx][tr][ig] - (xs[idx][scat][ig] + xs[idx][ab][ig])

  # Calculate Scalar Flux (phi_lgi)
  for l in range(1):
    for idx in range(nmesh):
      for ig in range(ng):
        #scal_flux[idx][ig][l] = 0.0
        #for m in range(norder):
        scal_flux[idx][ig][l] = phi[idx][ig]
    
  # Calculate Source Terms (S_fi)
  sfdx = 0
  for idx in range(nmesh):
    sn_sf[idx] = 0.0
    for ig in range(ng):
      sn_sf[idx] += xs[idx][nf][ig]*scal_flux[idx][ig][0]
    sfdx += sn_sf[idx] * geom[idx]

  for m in range(norder):
    for idx in range(nmesh):
      for ig in range(ng):
        sn_ss[idx][ig][m] = 0.0
        for g in range(ng):
          for l in range(1):
            if ig != g:
              sn_ss[idx][ig][m] += (2*l+1) * 0.5 *scal_flux[idx][g][l]*Plm[l][m]*xs[idx][scat][g]
            else:
              sn_ss[idx][ig][m] += (2*l+1) * 0.5 *scal_flux[idx][ig][l]*Plm[l][m]*scat_gg[idx][ig]
        sn_source[idx][ig][m] = sn_ss[idx][ig][m] + lamb*Chi[idx][ig]*sn_sf[idx] * 0.5

  # Set Sn Linear System and Solve Surface Angular Flux for Interior
  for m in range(norder//2):
    pm = norder-m-1
    for ig in range(ng):
      #solve for m angle
      surf_ang_flux[nmesh][ig][m] = beta_r*surf_ang_flux[nmesh][ig][pm]
      for idx in range(nmesh-1,-1,-1):
        surf_ang_flux[idx][ig][m] = (geom[idx] * sn_source[idx][ig][m] - \
        (geom[idx]/2 * xs[idx][tr][ig] + mu[m]) * surf_ang_flux[idx+1][ig][m])/ \
        (geom[idx]/2 * xs[idx][tr][ig] - mu[m])
      #solve for pm angle
      surf_ang_flux[0][ig][pm] = beta_l*surf_ang_flux[0][ig][m]
      for idx in range(1,nmesh+1):
        surf_ang_flux[idx][ig][pm] = (geom[idx-1] * sn_source[idx-1][ig][pm] - \
        (geom[idx-1]/2* xs[idx-1][tr][ig] - mu[pm]) * surf_ang_flux[idx-1][ig][pm])/ \
        (geom[idx-1]/2* xs[idx-1][tr][ig] + mu[pm])

      # Evaluate interior angular flux
        for idx in range(nmesh):
          ang_flux[idx][ig][m] = 0.5 * (surf_ang_flux[idx][ig][m] + surf_ang_flux[idx+1][ig][m])
          ang_flux[idx][ig][pm] = 0.5 * (surf_ang_flux[idx][ig][pm] + surf_ang_flux[idx+1][ig][pm])

  # Evaluate scalar flux (zeroth moment)
  for idx in range(nmesh):
    for ig in range(ng):
      phi[idx][ig] = 0.0
      for m in range(norder):
        phi[idx][ig] += w[m]*ang_flux[idx][ig][m]

  #plt.plot(surf_ang_flux[:,0,0])
  #plt.plot(surf_ang_flux[:,1,0])
  #plt.plot(surf_ang_flux[:,0,1])
  #plt.plot(surf_ang_flux[:,1,1])
  #plt.legend(["surf_ang_flux1m0","surf_ang_flux2m0","surf_ang_flux1m1","surf_ang_flux2m1"])
  #plt.show()

  # Evaluate current and D-hat
  curns_array = np.zeros([nmesh+1,ng])
  for idx in range(nmesh+1):
    for ig in range(ng):
      curns_array[idx][ig] = 0.0
      for m in range(norder):
        curns_array[idx][ig] += w[m]*mu[m]*surf_ang_flux[idx][ig][m]
      
      if idx==0:
        if BC[0] > 0:
          num = curns_array[idx][ig] - Dtilda[idx][ig]*(0 - phi[idx][ig])
          denom = 0 + phi[idx][ig]
          D_hat[idx][ig] = num/denom
        else:
          D_hat[idx][ig] = 0
      elif idx==nmesh:
        if BC[1] > 0:
          num = curns_array[idx][ig] - Dtilda[idx][ig]*(phi[idx-1][ig] - 0)
          denom = phi[idx-1][ig] + 0
          D_hat[idx][ig] = num/denom 
        else:
          D_hat[idx][ig] = 0     
      else:
        num = curns_array[idx][ig] - Dtilda[idx][ig]*(phi[idx-1][ig] - phi[idx][ig])
        denom = phi[idx-1][ig] + phi[idx][ig]
        D_hat[idx][ig] = num/denom

      #print("D_hat idx ig",idx,ig,D_hat[idx][ig])
  #plt.plot(curns_array[:,0])
  #plt.plot(curns_array[:,1])
  #plt.legend(["curns1","curns2"])
  #plt.plot(D_hat[:,0])
  #plt.plot(D_hat[:,1])
  #plt.legend(["D_hat1","D_hat2"])
  #plt.show()
          

  return

# %% [markdown]
# ## Sn Stand alone

# %%
def Sn_standalone():

  global geom, phi, lamb, lamb_prev, \
          iter, iter_max, nmesh, curns, Keff, wiel, psi, psid, sf, ss, sf_prev, Am, src
  print("beta_l: " + str(beta_l) + " beta_r: " + str(beta_r))
  print("initial lamb: " + str(lamb) + "  |   inital keff: " + str(Keff) + "  |  norder: " + str(norder))

  # Initialize error and tolerance
  tol1 = 1E-7
  tol2 = 1E-5
  error1 = np.abs(lamb-lamb_prev)/lamb_prev
  error2 = 0.0
  for idx in range(nmesh):
    sf_change = np.abs(sf[idx] - sf_prev[idx])/sf_prev[idx]
    error2 = max(sf_change,error2)
  
  mu, w = roots_legendre(norder)
  Plm = np.zeros([norder+1, norder])
  for l in range(norder+1):
    Plm[l] = eval_legendre(l,mu)

  # Prepare self-scattering data
  scat_gg = np.zeros([nmesh, ng])
  for idx in range(nmesh):
    for ig in range(ng):
      scat_gg[idx][ig] = xs[idx][tr][ig] - (xs[idx][scat][ig] + xs[idx][ab][ig])

  # Start outer iteration
  errors = []
  while (error1>tol1):
    if iter >= iter_max:
      print("WARNING: Iteration finished without convergence")
      break
    # Calculate Scalar Flux (phi_lgi)
    for l in range(norder+1):
      for idx in range(nmesh):
        for ig in range(ng):
          scal_flux[idx][ig][l] = 0.0
          for m in range(norder):
            scal_flux[idx][ig][l] += w[m]*ang_flux[idx][ig][m]*Plm[l][m]
    
    # Calculate Source Terms (S_fi)
    sfdx = 0
    for idx in range(nmesh):
      sn_sf[idx] = 0.0
      for ig in range(ng):
        sn_sf[idx] += xs[idx][nf][ig]*scal_flux[idx][ig][0]
      sfdx += sn_sf[idx] * geom[idx]

    for m in range(norder):
      for idx in range(nmesh):
        for ig in range(ng):
          sn_ss[idx][ig][m] = 0.0
          for g in range(ng):
            for l in range(1):
              if ig != g:
                sn_ss[idx][ig][m] += (2*l+1) * 0.5 *scal_flux[idx][g][l]*Plm[l][m]*xs[idx][scat][g]
              else:
                sn_ss[idx][ig][m] += (2*l+1) * 0.5 *scal_flux[idx][ig][l]*Plm[l][m]*scat_gg[idx][ig]
          sn_source[idx][ig][m] = sn_ss[idx][ig][m] + lamb*Chi[idx][ig]*sn_sf[idx] * 0.5

    # Set Sn Linear System and Solve Surface Angular Flux for Interior
    for m in range(norder//2):
      pm = norder-m-1
      for ig in range(ng):
        #solve for m angle
        surf_ang_flux[nmesh][ig][m] = beta_r*surf_ang_flux[nmesh][ig][pm]
        for idx in range(nmesh-1,-1,-1):
          surf_ang_flux[idx][ig][m] = (geom[idx] * sn_source[idx][ig][m] - \
          (geom[idx]/2 * xs[idx][tr][ig] + mu[m]) * surf_ang_flux[idx+1][ig][m])/ \
          (geom[idx]/2 * xs[idx][tr][ig] - mu[m])
        #solve for pm angle
        surf_ang_flux[0][ig][pm] = beta_l*surf_ang_flux[0][ig][m]
        for idx in range(1,nmesh+1):
          surf_ang_flux[idx][ig][pm] = (geom[idx-1] * sn_source[idx-1][ig][pm] - \
          (geom[idx-1]/2* xs[idx-1][tr][ig] - mu[pm]) * surf_ang_flux[idx-1][ig][pm])/ \
          (geom[idx-1]/2* xs[idx-1][tr][ig] + mu[pm])
        
        # Evaluate interior angular flux
        for idx in range(nmesh):
          ang_flux[idx][ig][m] = 0.5 * (surf_ang_flux[idx][ig][m] + surf_ang_flux[idx+1][ig][m])
          ang_flux[idx][ig][pm] = 0.5 * (surf_ang_flux[idx][ig][pm] + surf_ang_flux[idx+1][ig][pm])

    # Evaluate scalar flux (zeroth moment)
    Curn_Sn = np.zeros([nmesh+1, ng])
    for idx in range(nmesh):
      for ig in range(ng):
        phi[idx][ig] = 0.0
        for m in range(norder):
          phi[idx][ig] += w[m]*ang_flux[idx][ig][m]

    for idx in range(nmesh+1):
      for ig in range(ng):
       summ = 0.0
       for m in range(norder):
         summ = summ + w[m]*mu[m]*surf_ang_flux[idx][ig][m]
       Curn_Sn[idx][ig] = summ
    """
    plt.plot(Curn_Sn[:,0])
    plt.plot(Curn_Sn[:,1])
    plt.legend(["sn_curns1","sn_curns2"])
    plt.show()
    """
    # Update sources
    sf_prev = sf.copy()
    sfdxo = sfdx
    sfdx = 0
    for idx in range(nmesh):
      sn_sf[idx] = 0
      for g in range(ng):
        sn_sf[idx] += phi[idx][g] * xs[idx][nf][g]   # fission source
      sfdx = sfdx + sn_sf[idx] * geom[idx]
    
    # Update eigenvalue
    lamb_prev = lamb
    lamb = lamb_prev * sfdxo / sfdx
    Keff = 1 / lamb

    # Update error
    error1 = np.abs(lamb - lamb_prev)/lamb_prev
    error2 = 0.0
    for idx in range(nmesh):
      sf_change = np.abs(sf[idx]-sf_prev[idx])/sf_prev[idx]
      error2 = max(sf_change,error2) 
    errors.append(error1)
    
    if show_iter:
      print(f"iter {iter:03d}:  lamb: {lamb:.5f}  Keff:{Keff:.5f}   lambda_err: {error1:.3e}   fission_err: {error2:.3e}")
    iter += 1
  
  # Normalize flux
  scale = phi[0][0]#max(phi[0,:])
  phi[:,0] = phi[:,0]/scale
  phi[:,1] = phi[:,1]/scale   


  return

# %% [markdown]
# ## P3 (Pn method)

# %% [markdown]
# #P3 stand alone

# %%
def SetLS0():
  '''
  Sets up linear system for phi0.
  '''
  global xs, geom, nmesh, A1, A2, A12, A21, Dtilda, sf, ss, lamb, Am, src, \
          phi, phi2
  
  # Prepare self-scattering data
  scat_gg = np.zeros([nmesh, ng])
  for idx in range(nmesh):
    for ig in range(ng):
      scat_gg[idx][ig] = xs[idx][tr][ig] - (xs[idx][scat][ig] + xs[idx][ab][ig])

  for idx in range(nmesh):
    xst1 = xs[idx][ab][0] + xs[idx][scat][0] + scat_gg[idx][0]
    xst2 = xs[idx][ab][1] + xs[idx][scat][1] + scat_gg[idx][1]
    
    A1[idx][idx] = Dtilda[idx][0] + Dtilda[idx+1][0] + geom[idx]*xst1
    A2[idx][idx] = Dtilda[idx][1] + Dtilda[idx+1][1] + geom[idx]*xst2
    A12[idx][idx] = 0.0
    A21[idx][idx] = 0.0

    # left BC  
    if idx == 0: 
      A1[idx][idx+1] = -Dtilda[idx+1][0]
      A2[idx][idx+1] = -Dtilda[idx+1][1]
    
    # right BC
    elif idx == nmesh-1:
      A1[idx][idx-1] = -Dtilda[idx][0]
      A2[idx][idx-1] = -Dtilda[idx][1]
    
    # interior
    else:
      A1[idx][idx-1] = -Dtilda[idx][0]
      A2[idx][idx-1] = -Dtilda[idx][1]
      A1[idx][idx+1] = -Dtilda[idx+1][0]
      A2[idx][idx+1] = -Dtilda[idx+1][1]
    
    ss1=phi[idx][1] * xs[idx][scat][1] + phi[idx][0] * scat_gg[idx][0]
    ss2=phi[idx][0] * xs[idx][scat][0] + phi[idx][1] * scat_gg[idx][1]
    b1[idx]  = (ss1 + Chi[idx,0]*sf[idx]*lamb + 2*xst1*phi2[idx][0]) * geom[idx]
    b2[idx]  = (ss2 + Chi[idx,1]*sf[idx]*lamb + 2*xst2*phi2[idx][1]) * geom[idx]

  Am = np.vstack([np.hstack([A1, A21]), np.hstack([A12, A2])])
  src = np.hstack([b1,b2])

  return

# %%
def SetLS2():
  '''
  Sets up linear system for phi2.
  '''
  global xs, geom, nmesh, Dtilda, lamb, Am_m2, \
          b1_m2, b2_m2, src_m2, phim0, phi, sf

  # Prepare self-scattering data
  scat_gg = np.zeros([nmesh, ng])
  for idx in range(nmesh):
    for ig in range(ng):
      scat_gg[idx][ig] = xs[idx][tr][ig] - (xs[idx][scat][ig] + xs[idx][ab][ig])

  for idx in range(nmesh):
    xst1 = xs[idx][ab][0] + xs[idx][scat][0] + scat_gg[idx][0]
    xst2 = xs[idx][ab][1] + xs[idx][scat][1] + scat_gg[idx][1]
    
    A1[idx][idx] = 9/7*Dtilda[idx][0] + 9/7*Dtilda[idx+1][0] + 3*geom[idx]*xst1
    A2[idx][idx] = 9/7*Dtilda[idx][1] + 9/7*Dtilda[idx+1][1] + 3*geom[idx]*xst2
    A12[idx][idx] = 0.0
    A21[idx][idx] = 0.0

    # left BC  
    if idx == 0: 
      A1[idx][idx+1] = -9/7*Dtilda[idx+1][0]
      A2[idx][idx+1] = -9/7*Dtilda[idx+1][1]
    
    # right BC
    elif idx == nmesh-1:
      A1[idx][idx-1] = -9/7*Dtilda[idx][0]
      A2[idx][idx-1] = -9/7*Dtilda[idx][1]
    
    # interior
    else:
      A1[idx][idx-1] = -9/7*Dtilda[idx][0]
      A2[idx][idx-1] = -9/7*Dtilda[idx][1]
      A1[idx][idx+1] = -9/7*Dtilda[idx+1][0]
      A2[idx][idx+1] = -9/7*Dtilda[idx+1][1]
    
    ss1=phi[idx][1] * xs[idx][scat][1] + phi[idx][0] * scat_gg[idx][0]
    ss2=phi[idx][0] * xs[idx][scat][0] + phi[idx][1] * scat_gg[idx][1]
    b1_m2[idx] = -2/3*(ss1 + Chi[idx,0]*sf[idx]*lamb - xst1*phim0[idx][0]) * geom[idx]
    b2_m2[idx] = -2/3*(ss2 + Chi[idx,1]*sf[idx]*lamb - xst2*phim0[idx][1]) * geom[idx]
  
  Am_m2 = np.vstack([np.hstack([A1, A21]), np.hstack([A12, A2])])
  src_m2 = np.hstack([b1_m2,b2_m2])

  return

# %%
def Pn_standalone():
  '''
  FDM method with SP3. No CMFD.
  '''
  global geom, phi, lamb, lamb_prev, Dtilda, D_hat, D2tilda, A1, A2, A12, A21, \
          b1, b2, iter, iter_max, nmesh, curns, Keff, wiel, psi, psid, sf, ss, \
          sf_prev, Am, src, Am_m2, src_m2, bcval

  # Initialize error and tolerance
  tol1 = 1E-7
  tol2 = 1E-5
  error1 = np.abs(lamb-lamb_prev)/lamb_prev
  error2 = 0.0
  for idx in range(nmesh):
    sf_change = np.abs(sf[idx] - sf_prev[idx])/sf_prev[idx]
    error2 = max(sf_change,error2)

  # Diffusion Coefficients
  #for idx in range(nmesh):  
  #  Dc[idx] = 1/3*np.reciprocal(xs[idx][tr])

  # Initialze D_tilda
  for idx in range(nmesh+1):
    for g in range(ng):
      if idx==0:
        if bcval[0] == 0:
          Dtilda[idx][g] = 0
        else:
          Dtilda[idx][g] = 1/(1/bcval[0] + geom[0]/(2*Dc[0][g]))
      elif idx==nmesh:
        if bcval[1] == 0:
          Dtilda[idx][g] = 0
        else:
          Dtilda[idx][g] = 1/(1/bcval[1] + geom[nmesh-1]/(2*Dc[nmesh-1][g]))
      else: 
        Dtilda[idx][g] = 1/(geom[idx-1]/(2*Dc[idx-1][g]) + geom[idx]/(2*Dc[idx][g]))
  
  # Start outer iteration
  errors = []
  while (error1>tol1 or error2>tol2):
    if iter >= iter_max:
      print("WARNING: Iteration finished without convergence")
      break

    # Sets 0th moment linear system
    SetLS0()

    # Solve
    sol = np.linalg.solve(Am, src)
    phim0[:,0] = sol[:nmesh]
    phim0[:,1] = sol[nmesh:]

    # Sets 2nd moment linear system
    SetLS2()

    # Solve
    sol = np.linalg.solve(Am_m2, src_m2)
    phi2[:,0] = sol[:nmesh]
    phi2[:,1] = sol[nmesh:]

    # Update flux
    for idx in range(nmesh):
      for g in range(ng):
        phi[idx][g] = phim0[idx][g] - 2*phi2[idx][g]
    
    # Update sources
    sf_prev = sf.copy()
    sf,ss = np.zeros([nmesh]),np.zeros([nmesh])
    for idx in range(nmesh):
      for g in range(ng):
        sf[idx] += phi[idx][g] * xs[idx][nf][g]   # fission source
        ss[idx] += phi[idx][g] * xs[idx][scat][g] # scattering source
      # psi[idx] = sf[idx] * geom[idx]
    
    # Update eigenvalue
    UpdateEigen()

    # Update error
    error1 = np.abs(lamb-lamb_prev)/lamb_prev
    error2 = 0.0
    for idx in range(nmesh):
      sf_change = np.abs(sf[idx]-sf_prev[idx])/sf_prev[idx]
      error2 = max(sf_change,error2) 
    errors.append(error1)
    
    if show_iter:
      print(f"iter {iter:03d}:  Keff:{Keff:.5f}   lambda_err: {error1:.3e}   fission_err: {error2:.3e}")
    iter += 1

  # Normalize flux
  Normalize()

  return errors

# %% [markdown]
# # P3 Driver

# %%
def Pn_driver():
  
  global geom, phi, lamb, lamb_prev, Dtilda, D_hat, D2tilda, A1, A2, A12, A21, \
          b1, b2, iter, iter_max, nmesh, curns, Keff, wiel, psi, psid, sf, ss, \
          sf_prev, Am, src, Am_m2, src_m2, bcval

  # Update sources
  sf_prev = sf.copy()
  sf,ss = np.zeros([nmesh]),np.zeros([nmesh])
  for idx in range(nmesh):
    for g in range(ng):
      sf[idx] += phi[idx][g] * xs[idx][nf][g]   # fission source
  
  # Set and solve linear system    
  SetLS0()
    
  # Solve
  sol = np.linalg.solve(Am, src)
  phim0[:,0] = sol[:nmesh]
  phim0[:,1] = sol[nmesh:]
    
  # Sets 2nd moment linear system
  SetLS2()

  # Solve
  sol = np.linalg.solve(Am_m2, src_m2)
  phi2[:,0] = sol[:nmesh]
  phi2[:,1] = sol[nmesh:]
  
  #find phi0, aka phi
  for idx in range(nmesh):
    for g in range(ng):
      phi[idx][g] = phim0[idx][g] - 2 * phi2[idx][g]
    
  # Evaluate current and update D-hat
  curns_array = np.zeros([nmesh+1,ng])
  for idx in range(nmesh+1):
    for ig in range(ng):
      if idx == 0:
        if BC[0] > 0:
          curns_array[idx][ig] = Dtilda[idx][ig]*(0 - phim0[idx][ig])
          num = curns_array[idx][ig] - Dtilda[idx][ig]*(0 - phi[idx][ig])
          denom = 0 + phi[idx][ig]
          D_hat[idx][ig] = num/denom
        else:
          D_hat[idx][ig] = 0
      
      elif idx == nmesh:
        if BC[1] > 0:
          curns_array[idx,ig] = Dtilda[idx][ig]*(phim0[idx-1][ig] - 0)
          num = curns_array[idx][ig] - Dtilda[idx][ig]*(phi[idx-1][ig] - 0)
          denom = phi[idx-1][ig] + 0
          D_hat[idx][ig] = num/denom 
        else:
          D_hat[idx][ig] = 0
      
      else:
        curns_array[idx][ig] = Dtilda[idx][ig]*(phim0[idx-1][ig] - phim0[idx][ig])
        num = curns_array[idx][ig] - Dtilda[idx][ig]*(phi[idx-1][ig] - phi[idx][ig])
        denom = phi[idx-1][ig] + phi[idx][ig]
        D_hat[idx][ig] = num/denom
    
  return

# %% [markdown]
# ## Plot and Print Results

# %%
def plot_flux(pphi, nmesh, length, plot_type, phi_a, log=False, C=0):
  '''
  Plots flux distribution.
  '''
  global ng

  if plot_type == 'Analytical':
    num = len(pphi)
    nodes = np.linspace(0, 100, num)
  else:
    nodes = [float((i+1/2)*length) for i in range(nmesh)]

  colors = ('blue', 'red')
  for g in range(ng):
    plt.plot(nodes,(pphi[:,g]),label=f'Group {g+1}', color=colors[g])
  
  #plt.xticks([float(i*length) for i in range(nmesh+1)])
  plt.xlabel("x (cm)")
  plt.ylabel(r'$\phi$')
  if log:
    plt.yscale("linear")
  if plot_type == 'Analytical':
    plt.title(f"{plot_type} flux with C10 = 1 / C20 = {C:.06e}")
  else:
    plt.title(f"{plot_type} flux with {nmesh} meshes of length {length} cm")
  
  plt.legend()

  #plt.show()

  return

# %%
def plot_flux_diff(phi, nmesh, nregions, nmesh_pr, phi_a, log_plot):
  '''
  Prints and plots the flux differences between numerical and analytical
  '''
  phi_num_avg = []
  phi_ana_avg = []
  lenA = int((len(phi_a)-1)/nregions)
  lenA_mesh = int((len(phi_a))/nmesh)
  phi1_error = []
  phi2_error = []
  
  # Print errors
  print("Error between numerical and analytical solution per region:")
  for idx in range(nregions):
    val1 = sum(phi[slice(idx*nmesh_pr,(idx+1)*nmesh_pr)])/nmesh_pr
    phi_num_avg.append(val1)

    val2 = sum(phi_a[slice(idx*lenA,(idx+1)*lenA)])/lenA
    phi_ana_avg.append(val2)
    print(f"{idx+1}: {abs(val2 - val1)/val2}")

  # TODO: plot errors
  for imesh in range(nmesh):
    iA = int(np.rint((2*imesh+1)/2*len(phi_a)/nmesh))
    phi_ana = sum(phi_a[slice(imesh*lenA_mesh,(imesh+1)*lenA_mesh)])/lenA_mesh
    phi1_error.append(np.abs(1-phi[imesh][0]/phi_ana[0])*100)
    phi2_error.append(np.abs(1-phi[imesh][1]/phi_ana[1])*100)
  meshes = np.linspace(0.0,100.0,num=nmesh) 
  plt.plot(meshes,phi1_error)
  plt.plot(meshes,phi2_error)
  plt.ylabel("Flux Error(%)")
  plt.xlabel("Length (cm)")
  plt.legend(["Group 1","Group 2"])
  plt.show()
  
  return

# %% [markdown]
# # Testing

# %%
# Run the finite difference calculation
print("############ Run CMFD alone ##################")
lamb=lam_init
Keff=1/lamb
iter = 0
Solver = 0 #run cmfd without sn
#nmesh_per_region = 50
CMFD()
phicmfd = phi.copy();
keff_cmfd = 1/lamb
iter_cmfd = iter

print("############ Run CMFD-Sn(8) solver ##################")
lamb=lam_init
Keff=1/lamb
iter = 0
Solver = 1  #run cmfd with sn
#nmesh_per_region = 16
CMFD()
phisn8 = phi.copy();
keff_sn8 = 1/lamb
iter_sn8 = iter


print("############ Run CMFD-Sn(2) solver ##################")
lamb=lam_init
Keff=1/lamb
iter = 0
norder = 2
#nmesh_per_region = 50
Solver = 1  #run cmfd with sn
CMFD()
phisn2 = phi.copy();
keff_sn2 = 1/lamb
iter_sn2 = iter

print("############ Run CMFD-Sn(4) solver ##################")
lamb=lam_init
Keff=1/lamb
iter = 0
norder = 4
#nmesh_per_region = 50
Solver = 1  #run cmfd with sn
CMFD()
phisn4 = phi.copy();
keff_sn4 = 1/lamb
iter_sn4 = iter

print("############ Run CMFD-Sn(6) solver ##################")
lamb=lam_init
Keff=1/lamb
iter = 0
norder = 6
#nmesh_per_region = 50
Solver = 1  #run cmfd with sn
CMFD()
phisn6 = phi.copy();
keff_sn6 = 1/lamb
iter_sn6 = iter

print("############ Run CMFD-Pn solver ##################")
lamb=lam_init
Keff=1/lamb
iter = 0
#nmesh_per_region = 50
Solver = 2  #run cmfd with pn
CMFD()
phipn = phi.copy();
keff_pn = 1/lamb
iter_pn = iter

print("############ Run Sn solver ##################")
lamb=lam_init
Keff=1/lamb
iter = 0
Sn_standalone()
phisna = phi.copy();
keff_sna = 1/lamb
iter_sna = iter

print("############ Run Pn solver ##################")
lamb=lam_init
Keff=1/lamb
iter = 0
Pn_standalone()
phipna = phi.copy();
keff_pna = 1/lamb
iter_pna = iter

print("####################### kEFF #########################################")
print("cmfd-sn(8):             iter", iter_sn8, " keff:", keff_sn8)
print("nmesh_per_region: ", nmesh_per_region)
print("cmfd-sn(2):             iter", iter_sn2, " keff:", keff_sn2, "keff diff (pcm): ", (keff_sn2-keff_sn8)*1e5)
print("cmfd-sn(4):             iter", iter_sn4, " keff:", keff_sn4, "keff diff (pcm): ", (keff_sn4-keff_sn8)*1e5)
print("cmfd-sn(6):             iter", iter_sn6, " keff:", keff_sn6, "keff diff (pcm): ", (keff_sn6-keff_sn8)*1e5)
print("cmfd-alone (diffusion): iter", iter_cmfd, " keff:", keff_cmfd, "keff diff (pcm): ", (keff_cmfd-keff_sn8)*1e5)
print("cmfd-pn:                iter", iter_pn, " keff:", keff_pn, "keff diff (pcm): ", (keff_pn-keff_sn8)*1e5)
print("sn-alone:               iter", iter_sna, " keff:", keff_sna, "keff diff (pcm): ", (keff_sna-keff_sn8)*1e5)
print("pn-alone:               iter", iter_pna, " keff:", keff_pna, "keff diff (pcm): ", (keff_pna-keff_sn8)*1e5)
print("######################################################################")

x = np.linspace(0, 100, nmesh)

plt.plot(x, phisn8[:,0])
plt.plot(x, phisn2[:,0])
plt.plot(x, phisn4[:,0])
plt.plot(x, phisn6[:,0])
plt.plot(x, phicmfd[:,0])
plt.plot(x, phipn[:,0])
plt.legend(["Sn(8)","Sn(2)","Sn(4)","Sn(6)", "CMFD", "Pn3"])
plt.title("Group 1 phi")
plt.show()

plt.plot(x, abs(phisn2[:,0]-phisn8[:,0]) / phisn8[:,0] *100)
plt.plot(x, abs(phisn4[:,0]-phisn8[:,0]) / phisn8[:,0] *100)
plt.plot(x, abs(phisn6[:,0]-phisn8[:,0]) / phisn8[:,0] *100)
plt.plot(x, abs(phicmfd[:,0]-phisn8[:,0]) / phisn8[:,0] *100)
plt.plot(x, abs(phipn[:,0]-phisn8[:,0]) / phisn8[:,0] *100)
plt.yscale('log')
plt.legend(["Sn(2)","Sn(4)","Sn(6)", "CMFD", "Pn3"])
plt.title("Group 1 R.E (%)")
plt.show()

plt.plot(x, phisn8[:,1])
plt.plot(x, phisn2[:,1])
plt.plot(x, phisn4[:,1])
plt.plot(x, phisn6[:,1])
plt.plot(x, phicmfd[:,1])
plt.plot(x, phipn[:,1])
plt.legend(["Sn(8)","Sn(2)","Sn(4)","Sn(6)", "CMFD", "Pn3"])
plt.title("Group 2 phi")
plt.show()

plt.plot(x, abs(phisn2[:,1]-phisn8[:,1]) / phisn8[:,1] *100)
plt.plot(x, abs(phisn4[:,1]-phisn8[:,1]) / phisn8[:,1] *100)
plt.plot(x, abs(phisn6[:,1]-phisn8[:,1]) / phisn8[:,1] *100)
plt.plot(x, abs(phicmfd[:,1]-phisn8[:,1]) / phisn8[:,1] *100)
plt.plot(x, abs(phipn[:,1]-phisn8[:,1]) / phisn8[:,1] *100)
plt.yscale('log')
plt.legend(["Sn(2)","Sn(4)","Sn(6)", "CMFD", "Pn3"])
plt.title("Group 2 R.E (%)")
plt.show()
# Out:
# ############ Run CMFD alone ##################
# iter 000:  Keff:1.13591   lambda_err: 1.196e-01   fission_err: 8.550e-01
# iter 001:  Keff:1.21708   lambda_err: 6.669e-02   fission_err: 3.212e-01
# iter 002:  Keff:1.19107   lambda_err: 2.184e-02   fission_err: 1.450e-01
# iter 003:  Keff:1.22955   lambda_err: 3.129e-02   fission_err: 1.110e-01
# iter 004:  Keff:1.20268   lambda_err: 2.234e-02   fission_err: 4.414e-02
# iter 005:  Keff:1.22846   lambda_err: 2.099e-02   fission_err: 4.889e-02
# iter 006:  Keff:1.20821   lambda_err: 1.676e-02   fission_err: 1.923e-02
# iter 007:  Keff:1.22607   lambda_err: 1.457e-02   fission_err: 2.636e-02
# iter 008:  Keff:1.21176   lambda_err: 1.181e-02   fission_err: 1.493e-02
# iter 009:  Keff:1.22394   lambda_err: 9.951e-03   fission_err: 1.577e-02
# iter 010:  Keff:1.21416   lambda_err: 8.056e-03   fission_err: 1.053e-02
# iter 011:  Keff:1.22232   lambda_err: 6.675e-03   fission_err: 9.866e-03
# iter 012:  Keff:1.21577   lambda_err: 5.381e-03   fission_err: 7.090e-03
# iter 013:  Keff:1.22116   lambda_err: 4.413e-03   fission_err: 6.277e-03
# iter 014:  Keff:1.21685   lambda_err: 3.542e-03   fission_err: 4.669e-03
# iter 015:  Keff:1.22038   lambda_err: 2.886e-03   fission_err: 4.017e-03
# iter 016:  Keff:1.21756   lambda_err: 2.309e-03   fission_err: 3.040e-03
# iter 017:  Keff:1.21985   lambda_err: 1.874e-03   fission_err: 2.575e-03
# iter 018:  Keff:1.21803   lambda_err: 1.496e-03   fission_err: 1.966e-03
# iter 019:  Keff:1.21950   lambda_err: 1.211e-03   fission_err: 1.651e-03
# iter 020:  Keff:1.21833   lambda_err: 9.648e-04   fission_err: 1.267e-03
# iter 021:  Keff:1.21928   lambda_err: 7.795e-04   fission_err: 1.058e-03
# iter 022:  Keff:1.21852   lambda_err: 6.206e-04   fission_err: 8.150e-04
# iter 023:  Keff:1.21913   lambda_err: 5.009e-04   fission_err: 6.783e-04
# iter 024:  Keff:1.21865   lambda_err: 3.984e-04   fission_err: 5.233e-04
# iter 025:  Keff:1.21904   lambda_err: 3.214e-04   fission_err: 4.347e-04
# iter 026:  Keff:1.21873   lambda_err: 2.555e-04   fission_err: 3.358e-04
# iter 027:  Keff:1.21898   lambda_err: 2.060e-04   fission_err: 2.785e-04
# iter 028:  Keff:1.21878   lambda_err: 1.638e-04   fission_err: 2.153e-04
# iter 029:  Keff:1.21894   lambda_err: 1.320e-04   fission_err: 1.784e-04
# iter 030:  Keff:1.21881   lambda_err: 1.049e-04   fission_err: 1.380e-04
# iter 031:  Keff:1.21892   lambda_err: 8.453e-05   fission_err: 1.143e-04
# iter 032:  Keff:1.21883   lambda_err: 6.717e-05   fission_err: 8.843e-05
# iter 033:  Keff:1.21890   lambda_err: 5.412e-05   fission_err: 7.324e-05
# iter 034:  Keff:1.21885   lambda_err: 4.300e-05   fission_err: 5.666e-05
# iter 035:  Keff:1.21889   lambda_err: 3.465e-05   fission_err: 4.692e-05
# iter 036:  Keff:1.21886   lambda_err: 2.753e-05   fission_err: 3.630e-05
# iter 037:  Keff:1.21888   lambda_err: 2.218e-05   fission_err: 3.006e-05
# iter 038:  Keff:1.21886   lambda_err: 1.762e-05   fission_err: 2.326e-05
# iter 039:  Keff:1.21888   lambda_err: 1.420e-05   fission_err: 1.925e-05
# iter 040:  Keff:1.21887   lambda_err: 1.128e-05   fission_err: 1.490e-05
# iter 041:  Keff:1.21888   lambda_err: 9.086e-06   fission_err: 1.233e-05
# iter 042:  Keff:1.21887   lambda_err: 7.218e-06   fission_err: 9.544e-06
# iter 043:  Keff:1.21887   lambda_err: 5.815e-06   fission_err: 7.901e-06
# iter 044:  Keff:1.21887   lambda_err: 4.620e-06   fission_err: 6.114e-06
# iter 045:  Keff:1.21887   lambda_err: 3.722e-06   fission_err: 5.061e-06
# iter 046:  Keff:1.21887   lambda_err: 2.957e-06   fission_err: 3.916e-06
# iter 047:  Keff:1.21887   lambda_err: 2.382e-06   fission_err: 3.242e-06
# iter 048:  Keff:1.21887   lambda_err: 1.892e-06   fission_err: 2.509e-06
# iter 049:  Keff:1.21887   lambda_err: 1.525e-06   fission_err: 2.077e-06
# iter 050:  Keff:1.21887   lambda_err: 1.211e-06   fission_err: 1.607e-06
# iter 051:  Keff:1.21887   lambda_err: 9.757e-07   fission_err: 1.330e-06
# iter 052:  Keff:1.21887   lambda_err: 7.751e-07   fission_err: 1.029e-06
# iter 053:  Keff:1.21887   lambda_err: 6.245e-07   fission_err: 8.523e-07
# iter 054:  Keff:1.21887   lambda_err: 4.960e-07   fission_err: 6.594e-07
# iter 055:  Keff:1.21887   lambda_err: 3.997e-07   fission_err: 5.460e-07
# iter 056:  Keff:1.21887   lambda_err: 3.175e-07   fission_err: 4.224e-07
# iter 057:  Keff:1.21887   lambda_err: 2.558e-07   fission_err: 3.497e-07
# iter 058:  Keff:1.21887   lambda_err: 2.032e-07   fission_err: 2.706e-07
# iter 059:  Keff:1.21887   lambda_err: 1.637e-07   fission_err: 2.240e-07
# iter 060:  Keff:1.21887   lambda_err: 1.300e-07   fission_err: 1.733e-07
# iter 061:  Keff:1.21887   lambda_err: 1.048e-07   fission_err: 1.435e-07
# iter 062:  Keff:1.21887   lambda_err: 8.322e-08   fission_err: 1.110e-07
# ############ Run CMFD-Sn(8) solver ##################
# iter 000:  Keff:1.47715   lambda_err: 3.230e-01   fission_err: 5.477e-01
# iter 001:  Keff:1.01720   lambda_err: 4.522e-01   fission_err: 4.717e-01
# iter 002:  Keff:1.44290   lambda_err: 2.950e-01   fission_err: 6.907e-01
# iter 003:  Keff:1.04158   lambda_err: 3.853e-01   fission_err: 3.392e-01
# iter 004:  Keff:1.41104   lambda_err: 2.618e-01   fission_err: 4.202e-01
# iter 005:  Keff:1.06393   lambda_err: 3.262e-01   fission_err: 2.607e-01
# iter 006:  Keff:1.38326   lambda_err: 2.309e-01   fission_err: 3.041e-01
# iter 007:  Keff:1.08394   lambda_err: 2.761e-01   fission_err: 2.099e-01
# iter 008:  Keff:1.35945   lambda_err: 2.027e-01   fission_err: 2.351e-01
# iter 009:  Keff:1.10162   lambda_err: 2.340e-01   fission_err: 1.733e-01
# iter 010:  Keff:1.33914   lambda_err: 1.774e-01   fission_err: 1.883e-01
# iter 011:  Keff:1.11715   lambda_err: 1.987e-01   fission_err: 1.453e-01
# iter 012:  Keff:1.32183   lambda_err: 1.548e-01   fission_err: 1.541e-01
# iter 013:  Keff:1.13073   lambda_err: 1.690e-01   fission_err: 1.230e-01
# iter 014:  Keff:1.30708   lambda_err: 1.349e-01   fission_err: 1.280e-01
# iter 015:  Keff:1.14257   lambda_err: 1.440e-01   fission_err: 1.048e-01
# iter 016:  Keff:1.29450   lambda_err: 1.174e-01   fission_err: 1.073e-01
# iter 017:  Keff:1.15288   lambda_err: 1.228e-01   fission_err: 8.967e-02
# iter 018:  Keff:1.28375   lambda_err: 1.019e-01   fission_err: 9.053e-02
# iter 019:  Keff:1.16184   lambda_err: 1.049e-01   fission_err: 7.693e-02
# iter 020:  Keff:1.27455   lambda_err: 8.843e-02   fission_err: 7.676e-02
# iter 021:  Keff:1.16961   lambda_err: 8.972e-02   fission_err: 6.612e-02
# iter 022:  Keff:1.26668   lambda_err: 7.663e-02   fission_err: 6.532e-02
# iter 023:  Keff:1.17636   lambda_err: 7.679e-02   fission_err: 5.689e-02
# iter 024:  Keff:1.25994   lambda_err: 6.634e-02   fission_err: 5.572e-02
# iter 025:  Keff:1.18219   lambda_err: 6.577e-02   fission_err: 4.899e-02
# iter 026:  Keff:1.25394   lambda_err: 5.722e-02   fission_err: 4.763e-02
# iter 027:  Keff:1.18755   lambda_err: 5.590e-02   fission_err: 4.203e-02
# iter 028:  Keff:1.24815   lambda_err: 4.855e-02   fission_err: 4.048e-02
# iter 029:  Keff:1.19319   lambda_err: 4.606e-02   fission_err: 3.551e-02
# iter 030:  Keff:1.24234   lambda_err: 3.956e-02   fission_err: 3.346e-02
# iter 031:  Keff:1.19869   lambda_err: 3.641e-02   fission_err: 2.910e-02
# iter 032:  Keff:1.23692   lambda_err: 3.091e-02   fission_err: 2.678e-02
# iter 033:  Keff:1.20367   lambda_err: 2.763e-02   fission_err: 2.305e-02
# iter 034:  Keff:1.23222   lambda_err: 2.317e-02   fission_err: 2.071e-02
# iter 035:  Keff:1.20786   lambda_err: 2.017e-02   fission_err: 1.765e-02
# iter 036:  Keff:1.22842   lambda_err: 1.673e-02   fission_err: 1.552e-02
# iter 037:  Keff:1.21117   lambda_err: 1.424e-02   fission_err: 1.310e-02
# iter 038:  Keff:1.22551   lambda_err: 1.170e-02   fission_err: 1.131e-02
# iter 039:  Keff:1.21364   lambda_err: 9.784e-03   fission_err: 9.473e-03
# iter 040:  Keff:1.22340   lambda_err: 7.982e-03   fission_err: 8.056e-03
# iter 041:  Keff:1.21540   lambda_err: 6.586e-03   fission_err: 6.702e-03
# iter 042:  Keff:1.22193   lambda_err: 5.344e-03   fission_err: 5.635e-03
# iter 043:  Keff:1.21662   lambda_err: 4.368e-03   fission_err: 4.663e-03
# iter 044:  Keff:1.22093   lambda_err: 3.531e-03   fission_err: 3.887e-03
# iter 045:  Keff:1.21743   lambda_err: 2.868e-03   fission_err: 3.205e-03
# iter 046:  Keff:1.22026   lambda_err: 2.312e-03   fission_err: 2.655e-03
# iter 047:  Keff:1.21798   lambda_err: 1.871e-03   fission_err: 2.182e-03
# iter 048:  Keff:1.21982   lambda_err: 1.506e-03   fission_err: 1.799e-03
# iter 049:  Keff:1.21833   lambda_err: 1.215e-03   fission_err: 1.476e-03
# iter 050:  Keff:1.21953   lambda_err: 9.776e-04   fission_err: 1.213e-03
# iter 051:  Keff:1.21857   lambda_err: 7.876e-04   fission_err: 9.931e-04
# iter 052:  Keff:1.21934   lambda_err: 6.334e-04   fission_err: 8.145e-04
# iter 053:  Keff:1.21872   lambda_err: 5.100e-04   fission_err: 6.660e-04
# iter 054:  Keff:1.21922   lambda_err: 4.102e-04   fission_err: 5.453e-04
# iter 055:  Keff:1.21882   lambda_err: 3.302e-04   fission_err: 4.454e-04
# iter 056:  Keff:1.21914   lambda_err: 2.657e-04   fission_err: 3.643e-04
# iter 057:  Keff:1.21888   lambda_err: 2.139e-04   fission_err: 2.974e-04
# iter 058:  Keff:1.21909   lambda_err: 1.722e-04   fission_err: 2.430e-04
# iter 059:  Keff:1.21892   lambda_err: 1.387e-04   fission_err: 1.983e-04
# iter 060:  Keff:1.21906   lambda_err: 1.117e-04   fission_err: 1.620e-04
# iter 061:  Keff:1.21895   lambda_err: 9.000e-05   fission_err: 1.320e-04
# iter 062:  Keff:1.21903   lambda_err: 7.254e-05   fission_err: 1.079e-04
# iter 063:  Keff:1.21896   lambda_err: 5.850e-05   fission_err: 8.789e-05
# iter 064:  Keff:1.21902   lambda_err: 4.718e-05   fission_err: 7.179e-05
# iter 065:  Keff:1.21897   lambda_err: 3.808e-05   fission_err: 5.848e-05
# iter 066:  Keff:1.21901   lambda_err: 3.074e-05   fission_err: 4.778e-05
# iter 067:  Keff:1.21898   lambda_err: 2.482e-05   fission_err: 3.890e-05
# iter 068:  Keff:1.21901   lambda_err: 2.005e-05   fission_err: 3.179e-05
# iter 069:  Keff:1.21899   lambda_err: 1.621e-05   fission_err: 2.587e-05
# iter 070:  Keff:1.21900   lambda_err: 1.310e-05   fission_err: 2.116e-05
# iter 071:  Keff:1.21899   lambda_err: 1.060e-05   fission_err: 1.720e-05
# iter 072:  Keff:1.21900   lambda_err: 8.577e-06   fission_err: 1.408e-05
# iter 073:  Keff:1.21899   lambda_err: 6.943e-06   fission_err: 1.144e-05
# iter 074:  Keff:1.21900   lambda_err: 5.623e-06   fission_err: 9.377e-06
# iter 075:  Keff:1.21899   lambda_err: 4.555e-06   fission_err: 7.607e-06
# iter 076:  Keff:1.21900   lambda_err: 3.692e-06   fission_err: 6.246e-06
# iter 077:  Keff:1.21899   lambda_err: 2.993e-06   fission_err: 5.058e-06
# iter 078:  Keff:1.21900   lambda_err: 2.427e-06   fission_err: 4.163e-06
# iter 079:  Keff:1.21899   lambda_err: 1.969e-06   fission_err: 3.363e-06
# iter 080:  Keff:1.21900   lambda_err: 1.598e-06   fission_err: 2.776e-06
# iter 081:  Keff:1.21899   lambda_err: 1.298e-06   fission_err: 2.235e-06
# iter 082:  Keff:1.21900   lambda_err: 1.054e-06   fission_err: 1.853e-06
# iter 083:  Keff:1.21899   lambda_err: 8.562e-07   fission_err: 1.485e-06
# iter 084:  Keff:1.21900   lambda_err: 6.958e-07   fission_err: 1.238e-06
# iter 085:  Keff:1.21899   lambda_err: 5.656e-07   fission_err: 9.865e-07
# iter 086:  Keff:1.21900   lambda_err: 4.599e-07   fission_err: 8.278e-07
# iter 087:  Keff:1.21900   lambda_err: 3.741e-07   fission_err: 6.547e-07
# iter 088:  Keff:1.21900   lambda_err: 3.043e-07   fission_err: 5.544e-07
# iter 089:  Keff:1.21900   lambda_err: 2.477e-07   fission_err: 4.339e-07
# iter 090:  Keff:1.21900   lambda_err: 2.016e-07   fission_err: 3.720e-07
# iter 091:  Keff:1.21900   lambda_err: 1.641e-07   fission_err: 2.871e-07
# iter 092:  Keff:1.21900   lambda_err: 1.337e-07   fission_err: 2.502e-07
# iter 093:  Keff:1.21900   lambda_err: 1.089e-07   fission_err: 1.895e-07
# iter 094:  Keff:1.21900   lambda_err: 8.870e-08   fission_err: 1.688e-07
# ############ Run CMFD-Sn(2) solver ##################
# iter 000:  Keff:1.47901   lambda_err: 3.239e-01   fission_err: 1.102e+00
# iter 001:  Keff:1.01373   lambda_err: 4.590e-01   fission_err: 6.721e-01
# iter 002:  Keff:1.44632   lambda_err: 2.991e-01   fission_err: 1.255e+00
# iter 003:  Keff:1.04000   lambda_err: 3.907e-01   fission_err: 4.616e-01
# iter 004:  Keff:1.41254   lambda_err: 2.637e-01   fission_err: 6.541e-01
# iter 005:  Keff:1.06361   lambda_err: 3.281e-01   fission_err: 3.404e-01
# iter 006:  Keff:1.38354   lambda_err: 2.312e-01   fission_err: 4.274e-01
# iter 007:  Keff:1.08440   lambda_err: 2.759e-01   fission_err: 2.645e-01
# iter 008:  Keff:1.35898   lambda_err: 2.021e-01   fission_err: 3.104e-01
# iter 009:  Keff:1.10258   lambda_err: 2.325e-01   fission_err: 2.130e-01
# iter 010:  Keff:1.33821   lambda_err: 1.761e-01   fission_err: 2.392e-01
# iter 011:  Keff:1.11844   lambda_err: 1.965e-01   fission_err: 1.756e-01
# iter 012:  Keff:1.32063   lambda_err: 1.531e-01   fission_err: 1.910e-01
# iter 013:  Keff:1.13223   lambda_err: 1.664e-01   fission_err: 1.470e-01
# iter 014:  Keff:1.30572   lambda_err: 1.329e-01   fission_err: 1.560e-01
# iter 015:  Keff:1.14420   lambda_err: 1.412e-01   fission_err: 1.242e-01
# iter 016:  Keff:1.29306   lambda_err: 1.151e-01   fission_err: 1.293e-01
# iter 017:  Keff:1.15456   lambda_err: 1.200e-01   fission_err: 1.057e-01
# iter 018:  Keff:1.28230   lambda_err: 9.961e-02   fission_err: 1.082e-01
# iter 019:  Keff:1.16353   lambda_err: 1.021e-01   fission_err: 9.029e-02
# iter 020:  Keff:1.27314   lambda_err: 8.609e-02   fission_err: 9.111e-02
# iter 021:  Keff:1.17128   lambda_err: 8.696e-02   fission_err: 7.733e-02
# iter 022:  Keff:1.26533   lambda_err: 7.433e-02   fission_err: 7.709e-02
# iter 023:  Keff:1.17798   lambda_err: 7.416e-02   fission_err: 6.633e-02
# iter 024:  Keff:1.25867   lambda_err: 6.411e-02   fission_err: 6.545e-02
# iter 025:  Keff:1.18375   lambda_err: 6.330e-02   fission_err: 5.695e-02
# iter 026:  Keff:1.25261   lambda_err: 5.498e-02   fission_err: 5.570e-02
# iter 027:  Keff:1.18932   lambda_err: 5.322e-02   fission_err: 4.864e-02
# iter 028:  Keff:1.24668   lambda_err: 4.601e-02   fission_err: 4.692e-02
# iter 029:  Keff:1.19504   lambda_err: 4.321e-02   fission_err: 4.081e-02
# iter 030:  Keff:1.24087   lambda_err: 3.693e-02   fission_err: 3.849e-02
# iter 031:  Keff:1.20049   lambda_err: 3.363e-02   fission_err: 3.326e-02
# iter 032:  Keff:1.23557   lambda_err: 2.840e-02   fission_err: 3.060e-02
# iter 033:  Keff:1.20530   lambda_err: 2.512e-02   fission_err: 2.621e-02
# iter 034:  Keff:1.23110   lambda_err: 2.095e-02   fission_err: 2.354e-02
# iter 035:  Keff:1.20926   lambda_err: 1.806e-02   fission_err: 1.998e-02
# iter 036:  Keff:1.22755   lambda_err: 1.491e-02   fission_err: 1.755e-02
# iter 037:  Keff:1.21231   lambda_err: 1.258e-02   fission_err: 1.477e-02
# iter 038:  Keff:1.22491   lambda_err: 1.029e-02   fission_err: 1.273e-02
# iter 039:  Keff:1.21454   lambda_err: 8.537e-03   fission_err: 1.063e-02
# iter 040:  Keff:1.22302   lambda_err: 6.934e-03   fission_err: 9.025e-03
# iter 041:  Keff:1.21610   lambda_err: 5.685e-03   fission_err: 7.492e-03
# iter 042:  Keff:1.22172   lambda_err: 4.593e-03   fission_err: 6.280e-03
# iter 043:  Keff:1.21717   lambda_err: 3.734e-03   fission_err: 5.186e-03
# iter 044:  Keff:1.22084   lambda_err: 3.006e-03   fission_err: 4.306e-03
# iter 045:  Keff:1.21788   lambda_err: 2.429e-03   fission_err: 3.542e-03
# iter 046:  Keff:1.22026   lambda_err: 1.951e-03   fission_err: 2.919e-03
# iter 047:  Keff:1.21835   lambda_err: 1.570e-03   fission_err: 2.394e-03
# iter 048:  Keff:1.21988   lambda_err: 1.259e-03   fission_err: 1.962e-03
# iter 049:  Keff:1.21865   lambda_err: 1.011e-03   fission_err: 1.605e-03
# iter 050:  Keff:1.21964   lambda_err: 8.094e-04   fission_err: 1.309e-03
# iter 051:  Keff:1.21885   lambda_err: 6.488e-04   fission_err: 1.070e-03
# iter 052:  Keff:1.21948   lambda_err: 5.192e-04   fission_err: 8.688e-04
# iter 053:  Keff:1.21898   lambda_err: 4.157e-04   fission_err: 7.094e-04
# iter 054:  Keff:1.21938   lambda_err: 3.325e-04   fission_err: 5.740e-04
# iter 055:  Keff:1.21906   lambda_err: 2.660e-04   fission_err: 4.687e-04
# iter 056:  Keff:1.21932   lambda_err: 2.127e-04   fission_err: 3.779e-04
# iter 057:  Keff:1.21911   lambda_err: 1.701e-04   fission_err: 3.088e-04
# iter 058:  Keff:1.21927   lambda_err: 1.360e-04   fission_err: 2.480e-04
# iter 059:  Keff:1.21914   lambda_err: 1.087e-04   fission_err: 2.030e-04
# iter 060:  Keff:1.21925   lambda_err: 8.689e-05   fission_err: 1.623e-04
# iter 061:  Keff:1.21916   lambda_err: 6.946e-05   fission_err: 1.332e-04
# iter 062:  Keff:1.21923   lambda_err: 5.551e-05   fission_err: 1.060e-04
# iter 063:  Keff:1.21918   lambda_err: 4.437e-05   fission_err: 8.736e-05
# iter 064:  Keff:1.21922   lambda_err: 3.546e-05   fission_err: 6.900e-05
# iter 065:  Keff:1.21919   lambda_err: 2.834e-05   fission_err: 5.725e-05
# iter 066:  Keff:1.21921   lambda_err: 2.265e-05   fission_err: 4.481e-05
# iter 067:  Keff:1.21919   lambda_err: 1.810e-05   fission_err: 3.752e-05
# iter 068:  Keff:1.21921   lambda_err: 1.446e-05   fission_err: 2.902e-05
# iter 069:  Keff:1.21919   lambda_err: 1.156e-05   fission_err: 2.461e-05
# iter 070:  Keff:1.21921   lambda_err: 9.235e-06   fission_err: 1.873e-05
# iter 071:  Keff:1.21920   lambda_err: 7.380e-06   fission_err: 1.617e-05
# iter 072:  Keff:1.21920   lambda_err: 5.898e-06   fission_err: 1.204e-05
# iter 073:  Keff:1.21920   lambda_err: 4.713e-06   fission_err: 1.065e-05
# iter 074:  Keff:1.21920   lambda_err: 3.766e-06   fission_err: 7.697e-06
# iter 075:  Keff:1.21920   lambda_err: 3.010e-06   fission_err: 7.040e-06
# iter 076:  Keff:1.21920   lambda_err: 2.405e-06   fission_err: 4.884e-06
# iter 077:  Keff:1.21920   lambda_err: 1.922e-06   fission_err: 4.679e-06
# iter 078:  Keff:1.21920   lambda_err: 1.536e-06   fission_err: 3.068e-06
# iter 079:  Keff:1.21920   lambda_err: 1.227e-06   fission_err: 3.133e-06
# iter 080:  Keff:1.21920   lambda_err: 9.809e-07   fission_err: 1.900e-06
# iter 081:  Keff:1.21920   lambda_err: 7.840e-07   fission_err: 2.118e-06
# iter 082:  Keff:1.21920   lambda_err: 6.265e-07   fission_err: 1.330e-06
# iter 083:  Keff:1.21920   lambda_err: 5.007e-07   fission_err: 1.449e-06
# iter 084:  Keff:1.21920   lambda_err: 4.002e-07   fission_err: 9.454e-07
# iter 085:  Keff:1.21920   lambda_err: 3.199e-07   fission_err: 1.007e-06
# iter 086:  Keff:1.21920   lambda_err: 2.557e-07   fission_err: 6.834e-07
# iter 087:  Keff:1.21920   lambda_err: 2.044e-07   fission_err: 7.127e-07
# iter 088:  Keff:1.21920   lambda_err: 1.633e-07   fission_err: 5.038e-07
# iter 089:  Keff:1.21920   lambda_err: 1.306e-07   fission_err: 5.153e-07
# iter 090:  Keff:1.21920   lambda_err: 1.044e-07   fission_err: 3.793e-07
# iter 091:  Keff:1.21920   lambda_err: 8.345e-08   fission_err: 3.814e-07
# ############ Run CMFD-Sn(4) solver ##################
# iter 000:  Keff:1.46885   lambda_err: 3.192e-01   fission_err: 5.157e-01
# iter 001:  Keff:1.02417   lambda_err: 4.342e-01   fission_err: 1.048e+00
# iter 002:  Keff:1.43035   lambda_err: 2.840e-01   fission_err: 1.028e+00
# iter 003:  Keff:1.05069   lambda_err: 3.613e-01   fission_err: 3.949e-01
# iter 004:  Keff:1.39844   lambda_err: 2.487e-01   fission_err: 5.503e-01
# iter 005:  Keff:1.07316   lambda_err: 3.031e-01   fission_err: 2.984e-01
# iter 006:  Keff:1.37169   lambda_err: 2.176e-01   fission_err: 3.664e-01
# iter 007:  Keff:1.09266   lambda_err: 2.554e-01   fission_err: 2.338e-01
# iter 008:  Keff:1.34911   lambda_err: 1.901e-01   fission_err: 2.683e-01
# iter 009:  Keff:1.10964   lambda_err: 2.158e-01   fission_err: 1.883e-01
# iter 010:  Keff:1.33002   lambda_err: 1.657e-01   fission_err: 2.071e-01
# iter 011:  Keff:1.12442   lambda_err: 1.829e-01   fission_err: 1.547e-01
# iter 012:  Keff:1.31382   lambda_err: 1.442e-01   fission_err: 1.652e-01
# iter 013:  Keff:1.13726   lambda_err: 1.553e-01   fission_err: 1.289e-01
# iter 014:  Keff:1.30007   lambda_err: 1.252e-01   fission_err: 1.346e-01
# iter 015:  Keff:1.14841   lambda_err: 1.321e-01   fission_err: 1.085e-01
# iter 016:  Keff:1.28837   lambda_err: 1.086e-01   fission_err: 1.114e-01
# iter 017:  Keff:1.15808   lambda_err: 1.125e-01   fission_err: 9.204e-02
# iter 018:  Keff:1.27840   lambda_err: 9.412e-02   fission_err: 9.308e-02
# iter 019:  Keff:1.16645   lambda_err: 9.597e-02   fission_err: 7.842e-02
# iter 020:  Keff:1.26989   lambda_err: 8.145e-02   fission_err: 7.836e-02
# iter 021:  Keff:1.17369   lambda_err: 8.196e-02   fission_err: 6.704e-02
# iter 022:  Keff:1.26262   lambda_err: 7.043e-02   fission_err: 6.632e-02
# iter 023:  Keff:1.17995   lambda_err: 7.006e-02   fission_err: 5.744e-02
# iter 024:  Keff:1.25641   lambda_err: 6.085e-02   fission_err: 5.633e-02
# iter 025:  Keff:1.18536   lambda_err: 5.994e-02   fission_err: 4.929e-02
# iter 026:  Keff:1.25053   lambda_err: 5.211e-02   fission_err: 4.798e-02
# iter 027:  Keff:1.19098   lambda_err: 5.000e-02   fission_err: 4.191e-02
# iter 028:  Keff:1.24464   lambda_err: 4.311e-02   fission_err: 4.009e-02
# iter 029:  Keff:1.19661   lambda_err: 4.013e-02   fission_err: 3.480e-02
# iter 030:  Keff:1.23899   lambda_err: 3.420e-02   fission_err: 3.253e-02
# iter 031:  Keff:1.20186   lambda_err: 3.089e-02   fission_err: 2.800e-02
# iter 032:  Keff:1.23396   lambda_err: 2.601e-02   fission_err: 2.556e-02
# iter 033:  Keff:1.20640   lambda_err: 2.284e-02   fission_err: 2.180e-02
# iter 034:  Keff:1.22978   lambda_err: 1.901e-02   fission_err: 1.945e-02
# iter 035:  Keff:1.21006   lambda_err: 1.629e-02   fission_err: 1.643e-02
# iter 036:  Keff:1.22653   lambda_err: 1.342e-02   fission_err: 1.438e-02
# iter 037:  Keff:1.21285   lambda_err: 1.128e-02   fission_err: 1.204e-02
# iter 038:  Keff:1.22413   lambda_err: 9.216e-03   fission_err: 1.037e-02
# iter 039:  Keff:1.21486   lambda_err: 7.629e-03   fission_err: 8.608e-03
# iter 040:  Keff:1.22243   lambda_err: 6.193e-03   fission_err: 7.325e-03
# iter 041:  Keff:1.21626   lambda_err: 5.071e-03   fission_err: 6.039e-03
# iter 042:  Keff:1.22127   lambda_err: 4.098e-03   fission_err: 5.094e-03
# iter 043:  Keff:1.21722   lambda_err: 3.329e-03   fission_err: 4.173e-03
# iter 044:  Keff:1.22049   lambda_err: 2.682e-03   fission_err: 3.500e-03
# iter 045:  Keff:1.21785   lambda_err: 2.168e-03   fission_err: 2.850e-03
# iter 046:  Keff:1.21997   lambda_err: 1.743e-03   fission_err: 2.383e-03
# iter 047:  Keff:1.21826   lambda_err: 1.404e-03   fission_err: 1.929e-03
# iter 048:  Keff:1.21964   lambda_err: 1.127e-03   fission_err: 1.611e-03
# iter 049:  Keff:1.21853   lambda_err: 9.057e-04   fission_err: 1.296e-03
# iter 050:  Keff:1.21942   lambda_err: 7.264e-04   fission_err: 1.084e-03
# iter 051:  Keff:1.21871   lambda_err: 5.831e-04   fission_err: 8.653e-04
# iter 052:  Keff:1.21928   lambda_err: 4.674e-04   fission_err: 7.272e-04
# iter 053:  Keff:1.21882   lambda_err: 3.749e-04   fission_err: 5.749e-04
# iter 054:  Keff:1.21919   lambda_err: 3.004e-04   fission_err: 4.866e-04
# iter 055:  Keff:1.21890   lambda_err: 2.409e-04   fission_err: 3.802e-04
# iter 056:  Keff:1.21913   lambda_err: 1.930e-04   fission_err: 3.253e-04
# iter 057:  Keff:1.21894   lambda_err: 1.547e-04   fission_err: 2.503e-04
# iter 058:  Keff:1.21909   lambda_err: 1.240e-04   fission_err: 2.175e-04
# iter 059:  Keff:1.21897   lambda_err: 9.938e-05   fission_err: 1.640e-04
# iter 060:  Keff:1.21907   lambda_err: 7.965e-05   fission_err: 1.455e-04
# iter 061:  Keff:1.21899   lambda_err: 6.386e-05   fission_err: 1.068e-04
# iter 062:  Keff:1.21905   lambda_err: 5.119e-05   fission_err: 9.764e-05
# iter 063:  Keff:1.21900   lambda_err: 4.105e-05   fission_err: 6.913e-05
# iter 064:  Keff:1.21904   lambda_err: 3.292e-05   fission_err: 6.577e-05
# iter 065:  Keff:1.21901   lambda_err: 2.641e-05   fission_err: 4.434e-05
# iter 066:  Keff:1.21904   lambda_err: 2.119e-05   fission_err: 4.455e-05
# iter 067:  Keff:1.21902   lambda_err: 1.700e-05   fission_err: 2.810e-05
# iter 068:  Keff:1.21903   lambda_err: 1.365e-05   fission_err: 3.041e-05
# iter 069:  Keff:1.21902   lambda_err: 1.095e-05   fission_err: 1.752e-05
# iter 070:  Keff:1.21903   lambda_err: 8.796e-06   fission_err: 2.097e-05
# iter 071:  Keff:1.21902   lambda_err: 7.065e-06   fission_err: 1.265e-05
# iter 072:  Keff:1.21903   lambda_err: 5.676e-06   fission_err: 1.464e-05
# iter 073:  Keff:1.21902   lambda_err: 4.561e-06   fission_err: 9.246e-06
# iter 074:  Keff:1.21903   lambda_err: 3.666e-06   fission_err: 1.038e-05
# iter 075:  Keff:1.21902   lambda_err: 2.948e-06   fission_err: 6.866e-06
# iter 076:  Keff:1.21903   lambda_err: 2.371e-06   fission_err: 7.497e-06
# iter 077:  Keff:1.21902   lambda_err: 1.908e-06   fission_err: 5.189e-06
# iter 078:  Keff:1.21903   lambda_err: 1.535e-06   fission_err: 5.524e-06
# iter 079:  Keff:1.21903   lambda_err: 1.236e-06   fission_err: 3.997e-06
# iter 080:  Keff:1.21903   lambda_err: 9.951e-07   fission_err: 4.160e-06
# iter 081:  Keff:1.21903   lambda_err: 8.016e-07   fission_err: 3.139e-06
# iter 082:  Keff:1.21903   lambda_err: 6.459e-07   fission_err: 3.205e-06
# iter 083:  Keff:1.21903   lambda_err: 5.206e-07   fission_err: 2.513e-06
# iter 084:  Keff:1.21903   lambda_err: 4.198e-07   fission_err: 2.525e-06
# iter 085:  Keff:1.21903   lambda_err: 3.386e-07   fission_err: 2.049e-06
# iter 086:  Keff:1.21903   lambda_err: 2.732e-07   fission_err: 2.032e-06
# iter 087:  Keff:1.21903   lambda_err: 2.205e-07   fission_err: 1.697e-06
# iter 088:  Keff:1.21903   lambda_err: 1.780e-07   fission_err: 1.666e-06
# iter 089:  Keff:1.21903   lambda_err: 1.437e-07   fission_err: 1.427e-06
# iter 090:  Keff:1.21903   lambda_err: 1.161e-07   fission_err: 1.389e-06
# iter 091:  Keff:1.21903   lambda_err: 9.385e-08   fission_err: 1.213e-06
# ############ Run CMFD-Sn(6) solver ##################
# iter 000:  Keff:1.47289   lambda_err: 3.211e-01   fission_err: 5.144e-01
# iter 001:  Keff:1.02091   lambda_err: 4.427e-01   fission_err: 1.403e+00
# iter 002:  Keff:1.43433   lambda_err: 2.882e-01   fission_err: 1.037e+00
# iter 003:  Keff:1.04780   lambda_err: 3.689e-01   fission_err: 3.983e-01
# iter 004:  Keff:1.40195   lambda_err: 2.526e-01   fission_err: 5.552e-01
# iter 005:  Keff:1.07055   lambda_err: 3.096e-01   fission_err: 2.996e-01
# iter 006:  Keff:1.37476   lambda_err: 2.213e-01   fission_err: 3.672e-01
# iter 007:  Keff:1.09030   lambda_err: 2.609e-01   fission_err: 2.336e-01
# iter 008:  Keff:1.35181   lambda_err: 1.935e-01   fission_err: 2.670e-01
# iter 009:  Keff:1.10749   lambda_err: 2.206e-01   fission_err: 1.871e-01
# iter 010:  Keff:1.33241   lambda_err: 1.688e-01   fission_err: 2.048e-01
# iter 011:  Keff:1.12246   lambda_err: 1.870e-01   fission_err: 1.530e-01
# iter 012:  Keff:1.31595   lambda_err: 1.470e-01   fission_err: 1.626e-01
# iter 013:  Keff:1.13547   lambda_err: 1.590e-01   fission_err: 1.269e-01
# iter 014:  Keff:1.30197   lambda_err: 1.279e-01   fission_err: 1.320e-01
# iter 015:  Keff:1.14677   lambda_err: 1.353e-01   fission_err: 1.065e-01
# iter 016:  Keff:1.29007   lambda_err: 1.111e-01   fission_err: 1.089e-01
# iter 017:  Keff:1.15658   lambda_err: 1.154e-01   fission_err: 9.006e-02
# iter 018:  Keff:1.27992   lambda_err: 9.636e-02   fission_err: 9.080e-02
# iter 019:  Keff:1.16509   lambda_err: 9.856e-02   fission_err: 7.659e-02
# iter 020:  Keff:1.27125   lambda_err: 8.350e-02   fission_err: 7.634e-02
# iter 021:  Keff:1.17246   lambda_err: 8.425e-02   fission_err: 6.540e-02
# iter 022:  Keff:1.26383   lambda_err: 7.229e-02   fission_err: 6.455e-02
# iter 023:  Keff:1.17885   lambda_err: 7.209e-02   fission_err: 5.599e-02
# iter 024:  Keff:1.25748   lambda_err: 6.253e-02   fission_err: 5.481e-02
# iter 025:  Keff:1.18437   lambda_err: 6.173e-02   fission_err: 4.803e-02
# iter 026:  Keff:1.25157   lambda_err: 5.369e-02   fission_err: 4.669e-02
# iter 027:  Keff:1.18991   lambda_err: 5.182e-02   fission_err: 4.089e-02
# iter 028:  Keff:1.24570   lambda_err: 4.479e-02   fission_err: 3.916e-02
# iter 029:  Keff:1.19555   lambda_err: 4.195e-02   fission_err: 3.408e-02
# iter 030:  Keff:1.24000   lambda_err: 3.585e-02   fission_err: 3.192e-02
# iter 031:  Keff:1.20088   lambda_err: 3.258e-02   fission_err: 2.754e-02
# iter 032:  Keff:1.23484   lambda_err: 2.750e-02   fission_err: 2.518e-02
# iter 033:  Keff:1.20556   lambda_err: 2.429e-02   fission_err: 2.151e-02
# iter 034:  Keff:1.23050   lambda_err: 2.027e-02   fission_err: 1.923e-02
# iter 035:  Keff:1.20939   lambda_err: 1.746e-02   fission_err: 1.627e-02
# iter 036:  Keff:1.22708   lambda_err: 1.442e-02   fission_err: 1.426e-02
# iter 037:  Keff:1.21233   lambda_err: 1.217e-02   fission_err: 1.195e-02
# iter 038:  Keff:1.22453   lambda_err: 9.960e-03   fission_err: 1.030e-02
# iter 039:  Keff:1.21448   lambda_err: 8.272e-03   fission_err: 8.564e-03
# iter 040:  Keff:1.22271   lambda_err: 6.728e-03   fission_err: 7.291e-03
# iter 041:  Keff:1.21599   lambda_err: 5.523e-03   fission_err: 6.018e-03
# iter 042:  Keff:1.22145   lambda_err: 4.470e-03   fission_err: 5.078e-03
# iter 043:  Keff:1.21702   lambda_err: 3.640e-03   fission_err: 4.164e-03
# iter 044:  Keff:1.22061   lambda_err: 2.937e-03   fission_err: 3.494e-03
# iter 045:  Keff:1.21771   lambda_err: 2.378e-03   fission_err: 2.848e-03
# iter 046:  Keff:1.22005   lambda_err: 1.914e-03   fission_err: 2.382e-03
# iter 047:  Keff:1.21816   lambda_err: 1.545e-03   fission_err: 1.931e-03
# iter 048:  Keff:1.21968   lambda_err: 1.242e-03   fission_err: 1.614e-03
# iter 049:  Keff:1.21846   lambda_err: 1.000e-03   fission_err: 1.300e-03
# iter 050:  Keff:1.21944   lambda_err: 8.034e-04   fission_err: 1.088e-03
# iter 051:  Keff:1.21865   lambda_err: 6.462e-04   fission_err: 8.705e-04
# iter 052:  Keff:1.21929   lambda_err: 5.189e-04   fission_err: 7.317e-04
# iter 053:  Keff:1.21878   lambda_err: 4.171e-04   fission_err: 5.802e-04
# iter 054:  Keff:1.21919   lambda_err: 3.349e-04   fission_err: 4.910e-04
# iter 055:  Keff:1.21886   lambda_err: 2.691e-04   fission_err: 3.851e-04
# iter 056:  Keff:1.21912   lambda_err: 2.161e-04   fission_err: 3.293e-04
# iter 057:  Keff:1.21891   lambda_err: 1.737e-04   fission_err: 2.546e-04
# iter 058:  Keff:1.21908   lambda_err: 1.396e-04   fission_err: 2.209e-04
# iter 059:  Keff:1.21894   lambda_err: 1.122e-04   fission_err: 1.676e-04
# iter 060:  Keff:1.21905   lambda_err: 9.018e-05   fission_err: 1.484e-04
# iter 061:  Keff:1.21896   lambda_err: 7.253e-05   fission_err: 1.099e-04
# iter 062:  Keff:1.21903   lambda_err: 5.833e-05   fission_err: 9.992e-05
# iter 063:  Keff:1.21898   lambda_err: 4.694e-05   fission_err: 7.159e-05
# iter 064:  Keff:1.21902   lambda_err: 3.778e-05   fission_err: 6.755e-05
# iter 065:  Keff:1.21899   lambda_err: 3.042e-05   fission_err: 4.630e-05
# iter 066:  Keff:1.21902   lambda_err: 2.450e-05   fission_err: 4.592e-05
# iter 067:  Keff:1.21899   lambda_err: 1.974e-05   fission_err: 2.965e-05
# iter 068:  Keff:1.21901   lambda_err: 1.591e-05   fission_err: 3.144e-05
# iter 069:  Keff:1.21900   lambda_err: 1.283e-05   fission_err: 1.871e-05
# iter 070:  Keff:1.21901   lambda_err: 1.034e-05   fission_err: 2.173e-05
# iter 071:  Keff:1.21900   lambda_err: 8.347e-06   fission_err: 1.219e-05
# iter 072:  Keff:1.21901   lambda_err: 6.737e-06   fission_err: 1.519e-05
# iter 073:  Keff:1.21900   lambda_err: 5.440e-06   fission_err: 8.957e-06
# iter 074:  Keff:1.21901   lambda_err: 4.394e-06   fission_err: 1.077e-05
# iter 075:  Keff:1.21900   lambda_err: 3.551e-06   fission_err: 6.676e-06
# iter 076:  Keff:1.21900   lambda_err: 2.871e-06   fission_err: 7.767e-06
# iter 077:  Keff:1.21900   lambda_err: 2.322e-06   fission_err: 5.059e-06
# iter 078:  Keff:1.21900   lambda_err: 1.878e-06   fission_err: 5.705e-06
# iter 079:  Keff:1.21900   lambda_err: 1.520e-06   fission_err: 3.902e-06
# iter 080:  Keff:1.21900   lambda_err: 1.231e-06   fission_err: 4.277e-06
# iter 081:  Keff:1.21900   lambda_err: 9.967e-07   fission_err: 3.067e-06
# iter 082:  Keff:1.21900   lambda_err: 8.075e-07   fission_err: 3.276e-06
# iter 083:  Keff:1.21900   lambda_err: 6.544e-07   fission_err: 2.454e-06
# iter 084:  Keff:1.21900   lambda_err: 5.306e-07   fission_err: 2.563e-06
# iter 085:  Keff:1.21900   lambda_err: 4.303e-07   fission_err: 1.999e-06
# iter 086:  Keff:1.21900   lambda_err: 3.491e-07   fission_err: 2.048e-06
# iter 087:  Keff:1.21900   lambda_err: 2.833e-07   fission_err: 1.654e-06
# iter 088:  Keff:1.21900   lambda_err: 2.300e-07   fission_err: 1.667e-06
# iter 089:  Keff:1.21900   lambda_err: 1.867e-07   fission_err: 1.387e-06
# iter 090:  Keff:1.21900   lambda_err: 1.517e-07   fission_err: 1.381e-06
# iter 091:  Keff:1.21900   lambda_err: 1.232e-07   fission_err: 1.178e-06
# iter 092:  Keff:1.21900   lambda_err: 1.002e-07   fission_err: 1.160e-06
# iter 093:  Keff:1.21900   lambda_err: 8.142e-08   fission_err: 1.010e-06
# ############ Run CMFD-Pn solver ##################
# iter 000:  Keff:1.45733   lambda_err: 3.138e-01   fission_err: 1.942e+01
# iter 001:  Keff:1.03148   lambda_err: 4.129e-01   fission_err: 1.733e-01
# iter 002:  Keff:1.42170   lambda_err: 2.745e-01   fission_err: 1.868e-01
# iter 003:  Keff:1.05636   lambda_err: 3.458e-01   fission_err: 1.448e-01
# iter 004:  Keff:1.39109   lambda_err: 2.406e-01   fission_err: 1.553e-01
# iter 005:  Keff:1.07812   lambda_err: 2.903e-01   fission_err: 1.242e-01
# iter 006:  Keff:1.36517   lambda_err: 2.103e-01   fission_err: 1.312e-01
# iter 007:  Keff:1.09710   lambda_err: 2.444e-01   fission_err: 1.078e-01
# iter 008:  Keff:1.34330   lambda_err: 1.833e-01   fission_err: 1.114e-01
# iter 009:  Keff:1.11362   lambda_err: 2.062e-01   fission_err: 9.324e-02
# iter 010:  Keff:1.32483   lambda_err: 1.594e-01   fission_err: 9.484e-02
# iter 011:  Keff:1.12799   lambda_err: 1.745e-01   fission_err: 8.053e-02
# iter 012:  Keff:1.30919   lambda_err: 1.384e-01   fission_err: 8.082e-02
# iter 013:  Keff:1.14046   lambda_err: 1.479e-01   fission_err: 6.948e-02
# iter 014:  Keff:1.29592   lambda_err: 1.200e-01   fission_err: 6.894e-02
# iter 015:  Keff:1.15126   lambda_err: 1.257e-01   fission_err: 5.991e-02
# iter 016:  Keff:1.28465   lambda_err: 1.038e-01   fission_err: 5.886e-02
# iter 017:  Keff:1.16061   lambda_err: 1.069e-01   fission_err: 5.161e-02
# iter 018:  Keff:1.27507   lambda_err: 8.976e-02   fission_err: 5.029e-02
# iter 019:  Keff:1.16869   lambda_err: 9.102e-02   fission_err: 4.444e-02
# iter 020:  Keff:1.26690   lambda_err: 7.752e-02   fission_err: 4.300e-02
# iter 021:  Keff:1.17566   lambda_err: 7.760e-02   fission_err: 3.825e-02
# iter 022:  Keff:1.25993   lambda_err: 6.688e-02   fission_err: 3.678e-02
# iter 023:  Keff:1.18168   lambda_err: 6.622e-02   fission_err: 3.291e-02
# iter 024:  Keff:1.25379   lambda_err: 5.752e-02   fission_err: 3.147e-02
# iter 025:  Keff:1.18713   lambda_err: 5.616e-02   fission_err: 2.815e-02
# iter 026:  Keff:1.24791   lambda_err: 4.870e-02   fission_err: 2.672e-02
# iter 027:  Keff:1.19285   lambda_err: 4.615e-02   fission_err: 2.354e-02
# iter 028:  Keff:1.24201   lambda_err: 3.958e-02   fission_err: 2.177e-02
# iter 029:  Keff:1.19842   lambda_err: 3.637e-02   fission_err: 1.889e-02
# iter 030:  Keff:1.23653   lambda_err: 3.082e-02   fission_err: 1.700e-02
# iter 031:  Keff:1.20345   lambda_err: 2.748e-02   fission_err: 1.452e-02
# iter 032:  Keff:1.23179   lambda_err: 2.301e-02   fission_err: 1.273e-02
# iter 033:  Keff:1.20767   lambda_err: 1.997e-02   fission_err: 1.071e-02
# iter 034:  Keff:1.22797   lambda_err: 1.653e-02   fission_err: 9.169e-03
# iter 035:  Keff:1.21098   lambda_err: 1.403e-02   fission_err: 7.613e-03
# iter 036:  Keff:1.22508   lambda_err: 1.150e-02   fission_err: 6.395e-03
# iter 037:  Keff:1.21344   lambda_err: 9.588e-03   fission_err: 5.252e-03
# iter 038:  Keff:1.22298   lambda_err: 7.801e-03   fission_err: 4.345e-03
# iter 039:  Keff:1.21518   lambda_err: 6.417e-03   fission_err: 3.539e-03
# iter 040:  Keff:1.22153   lambda_err: 5.191e-03   fission_err: 2.896e-03
# iter 041:  Keff:1.21638   lambda_err: 4.230e-03   fission_err: 2.344e-03
# iter 042:  Keff:1.22054   lambda_err: 3.408e-03   fission_err: 1.903e-03
# iter 043:  Keff:1.21718   lambda_err: 2.759e-03   fission_err: 1.534e-03
# iter 044:  Keff:1.21989   lambda_err: 2.217e-03   fission_err: 1.238e-03
# iter 045:  Keff:1.21771   lambda_err: 1.786e-03   fission_err: 9.953e-04
# iter 046:  Keff:1.21946   lambda_err: 1.433e-03   fission_err: 8.009e-04
# iter 047:  Keff:1.21806   lambda_err: 1.151e-03   fission_err: 6.424e-04
# iter 048:  Keff:1.21918   lambda_err: 9.223e-04   fission_err: 5.157e-04
# iter 049:  Keff:1.21828   lambda_err: 7.397e-04   fission_err: 4.131e-04
# iter 050:  Keff:1.21900   lambda_err: 5.920e-04   fission_err: 3.311e-04
# iter 051:  Keff:1.21842   lambda_err: 4.742e-04   fission_err: 2.650e-04
# iter 052:  Keff:1.21889   lambda_err: 3.794e-04   fission_err: 2.122e-04
# iter 053:  Keff:1.21852   lambda_err: 3.037e-04   fission_err: 1.698e-04
# iter 054:  Keff:1.21881   lambda_err: 2.428e-04   fission_err: 1.358e-04
# iter 055:  Keff:1.21858   lambda_err: 1.943e-04   fission_err: 1.086e-04
# iter 056:  Keff:1.21877   lambda_err: 1.553e-04   fission_err: 8.690e-05
# iter 057:  Keff:1.21861   lambda_err: 1.242e-04   fission_err: 6.949e-05
# iter 058:  Keff:1.21873   lambda_err: 9.931e-05   fission_err: 5.557e-05
# iter 059:  Keff:1.21864   lambda_err: 7.940e-05   fission_err: 4.443e-05
# iter 060:  Keff:1.21872   lambda_err: 6.347e-05   fission_err: 3.552e-05
# iter 061:  Keff:1.21865   lambda_err: 5.074e-05   fission_err: 2.840e-05
# iter 062:  Keff:1.21870   lambda_err: 4.056e-05   fission_err: 2.271e-05
# iter 063:  Keff:1.21866   lambda_err: 3.242e-05   fission_err: 1.815e-05
# iter 064:  Keff:1.21870   lambda_err: 2.592e-05   fission_err: 1.451e-05
# iter 065:  Keff:1.21867   lambda_err: 2.072e-05   fission_err: 1.160e-05
# iter 066:  Keff:1.21869   lambda_err: 1.656e-05   fission_err: 9.277e-06
# iter 067:  Keff:1.21867   lambda_err: 1.324e-05   fission_err: 7.417e-06
# iter 068:  Keff:1.21869   lambda_err: 1.058e-05   fission_err: 5.930e-06
# iter 069:  Keff:1.21868   lambda_err: 8.455e-06   fission_err: 4.742e-06
# iter 070:  Keff:1.21868   lambda_err: 6.758e-06   fission_err: 3.792e-06
# iter 071:  Keff:1.21868   lambda_err: 5.402e-06   fission_err: 3.032e-06
# iter 072:  Keff:1.21868   lambda_err: 4.317e-06   fission_err: 2.425e-06
# iter 073:  Keff:1.21868   lambda_err: 3.451e-06   fission_err: 1.940e-06
# iter 074:  Keff:1.21868   lambda_err: 2.758e-06   fission_err: 1.552e-06
# iter 075:  Keff:1.21868   lambda_err: 2.204e-06   fission_err: 1.242e-06
# iter 076:  Keff:1.21868   lambda_err: 1.762e-06   fission_err: 9.939e-07
# iter 077:  Keff:1.21868   lambda_err: 1.408e-06   fission_err: 7.956e-07
# iter 078:  Keff:1.21868   lambda_err: 1.125e-06   fission_err: 6.370e-07
# iter 079:  Keff:1.21868   lambda_err: 8.996e-07   fission_err: 5.102e-07
# iter 080:  Keff:1.21868   lambda_err: 7.190e-07   fission_err: 4.088e-07
# iter 081:  Keff:1.21868   lambda_err: 5.746e-07   fission_err: 3.277e-07
# iter 082:  Keff:1.21868   lambda_err: 4.593e-07   fission_err: 2.628e-07
# iter 083:  Keff:1.21868   lambda_err: 3.671e-07   fission_err: 2.109e-07
# iter 084:  Keff:1.21868   lambda_err: 2.934e-07   fission_err: 1.694e-07
# iter 085:  Keff:1.21868   lambda_err: 2.345e-07   fission_err: 1.363e-07
# iter 086:  Keff:1.21868   lambda_err: 1.874e-07   fission_err: 1.098e-07
# iter 087:  Keff:1.21868   lambda_err: 1.498e-07   fission_err: 8.852e-08
# ############ Run Sn solver ##################
# beta_l: 1.0 beta_r: 1.0
# initial lamb: 1  |   inital keff: 1.0  |  norder: 6
# iter 000:  lamb: 0.99378  Keff:1.00626   lambda_err: 6.223e-03   fission_err: 0.000e+00
# iter 001:  lamb: 0.98584  Keff:1.01436   lambda_err: 7.982e-03   fission_err: 0.000e+00
# iter 002:  lamb: 0.97695  Keff:1.02360   lambda_err: 9.026e-03   fission_err: 0.000e+00
# iter 003:  lamb: 0.96759  Keff:1.03350   lambda_err: 9.578e-03   fission_err: 0.000e+00
# iter 004:  lamb: 0.95813  Keff:1.04370   lambda_err: 9.780e-03   fission_err: 0.000e+00
# iter 005:  lamb: 0.94880  Keff:1.05397   lambda_err: 9.738e-03   fission_err: 0.000e+00
# iter 006:  lamb: 0.93976  Keff:1.06410   lambda_err: 9.527e-03   fission_err: 0.000e+00
# iter 007:  lamb: 0.93111  Keff:1.07399   lambda_err: 9.203e-03   fission_err: 0.000e+00
# iter 008:  lamb: 0.92291  Keff:1.08353   lambda_err: 8.804e-03   fission_err: 0.000e+00
# iter 009:  lamb: 0.91520  Keff:1.09266   lambda_err: 8.361e-03   fission_err: 0.000e+00
# iter 010:  lamb: 0.90797  Keff:1.10136   lambda_err: 7.894e-03   fission_err: 0.000e+00
# iter 011:  lamb: 0.90123  Keff:1.10959   lambda_err: 7.419e-03   fission_err: 0.000e+00
# iter 012:  lamb: 0.89497  Keff:1.11735   lambda_err: 6.946e-03   fission_err: 0.000e+00
# iter 013:  lamb: 0.88917  Keff:1.12464   lambda_err: 6.482e-03   fission_err: 0.000e+00
# iter 014:  lamb: 0.88381  Keff:1.13147   lambda_err: 6.035e-03   fission_err: 0.000e+00
# iter 015:  lamb: 0.87885  Keff:1.13785   lambda_err: 5.606e-03   fission_err: 0.000e+00
# iter 016:  lamb: 0.87428  Keff:1.14379   lambda_err: 5.198e-03   fission_err: 0.000e+00
# iter 017:  lamb: 0.87008  Keff:1.14932   lambda_err: 4.812e-03   fission_err: 0.000e+00
# iter 018:  lamb: 0.86621  Keff:1.15446   lambda_err: 4.450e-03   fission_err: 0.000e+00
# iter 019:  lamb: 0.86264  Keff:1.15923   lambda_err: 4.111e-03   fission_err: 0.000e+00
# iter 020:  lamb: 0.85937  Keff:1.16364   lambda_err: 3.794e-03   fission_err: 0.000e+00
# iter 021:  lamb: 0.85636  Keff:1.16773   lambda_err: 3.499e-03   fission_err: 0.000e+00
# iter 022:  lamb: 0.85360  Keff:1.17150   lambda_err: 3.225e-03   fission_err: 0.000e+00
# iter 023:  lamb: 0.85107  Keff:1.17500   lambda_err: 2.971e-03   fission_err: 0.000e+00
# iter 024:  lamb: 0.84874  Keff:1.17822   lambda_err: 2.736e-03   fission_err: 0.000e+00
# iter 025:  lamb: 0.84660  Keff:1.18119   lambda_err: 2.519e-03   fission_err: 0.000e+00
# iter 026:  lamb: 0.84464  Keff:1.18394   lambda_err: 2.319e-03   fission_err: 0.000e+00
# iter 027:  lamb: 0.84283  Keff:1.18647   lambda_err: 2.134e-03   fission_err: 0.000e+00
# iter 028:  lamb: 0.84118  Keff:1.18881   lambda_err: 1.964e-03   fission_err: 0.000e+00
# iter 029:  lamb: 0.83966  Keff:1.19096   lambda_err: 1.808e-03   fission_err: 0.000e+00
# iter 030:  lamb: 0.83826  Keff:1.19295   lambda_err: 1.664e-03   fission_err: 0.000e+00
# iter 031:  lamb: 0.83698  Keff:1.19478   lambda_err: 1.532e-03   fission_err: 0.000e+00
# iter 032:  lamb: 0.83579  Keff:1.19647   lambda_err: 1.411e-03   fission_err: 0.000e+00
# iter 033:  lamb: 0.83471  Keff:1.19802   lambda_err: 1.300e-03   fission_err: 0.000e+00
# iter 034:  lamb: 0.83371  Keff:1.19946   lambda_err: 1.198e-03   fission_err: 0.000e+00
# iter 035:  lamb: 0.83279  Keff:1.20079   lambda_err: 1.104e-03   fission_err: 0.000e+00
# iter 036:  lamb: 0.83194  Keff:1.20201   lambda_err: 1.018e-03   fission_err: 0.000e+00
# iter 037:  lamb: 0.83116  Keff:1.20314   lambda_err: 9.389e-04   fission_err: 0.000e+00
# iter 038:  lamb: 0.83044  Keff:1.20418   lambda_err: 8.666e-04   fission_err: 0.000e+00
# iter 039:  lamb: 0.82977  Keff:1.20515   lambda_err: 8.002e-04   fission_err: 0.000e+00
# iter 040:  lamb: 0.82916  Keff:1.20604   lambda_err: 7.393e-04   fission_err: 0.000e+00
# iter 041:  lamb: 0.82859  Keff:1.20686   lambda_err: 6.834e-04   fission_err: 0.000e+00
# iter 042:  lamb: 0.82807  Keff:1.20763   lambda_err: 6.321e-04   fission_err: 0.000e+00
# iter 043:  lamb: 0.82759  Keff:1.20833   lambda_err: 5.850e-04   fission_err: 0.000e+00
# iter 044:  lamb: 0.82714  Keff:1.20899   lambda_err: 5.418e-04   fission_err: 0.000e+00
# iter 045:  lamb: 0.82672  Keff:1.20960   lambda_err: 5.021e-04   fission_err: 0.000e+00
# iter 046:  lamb: 0.82634  Keff:1.21016   lambda_err: 4.657e-04   fission_err: 0.000e+00
# iter 047:  lamb: 0.82598  Keff:1.21068   lambda_err: 4.322e-04   fission_err: 0.000e+00
# iter 048:  lamb: 0.82565  Keff:1.21117   lambda_err: 4.014e-04   fission_err: 0.000e+00
# iter 049:  lamb: 0.82534  Keff:1.21162   lambda_err: 3.731e-04   fission_err: 0.000e+00
# iter 050:  lamb: 0.82505  Keff:1.21204   lambda_err: 3.470e-04   fission_err: 0.000e+00
# iter 051:  lamb: 0.82479  Keff:1.21243   lambda_err: 3.230e-04   fission_err: 0.000e+00
# iter 052:  lamb: 0.82454  Keff:1.21280   lambda_err: 3.009e-04   fission_err: 0.000e+00
# iter 053:  lamb: 0.82431  Keff:1.21314   lambda_err: 2.805e-04   fission_err: 0.000e+00
# iter 054:  lamb: 0.82409  Keff:1.21346   lambda_err: 2.617e-04   fission_err: 0.000e+00
# iter 055:  lamb: 0.82389  Keff:1.21375   lambda_err: 2.444e-04   fission_err: 0.000e+00
# iter 056:  lamb: 0.82370  Keff:1.21403   lambda_err: 2.284e-04   fission_err: 0.000e+00
# iter 057:  lamb: 0.82353  Keff:1.21429   lambda_err: 2.136e-04   fission_err: 0.000e+00
# iter 058:  lamb: 0.82336  Keff:1.21453   lambda_err: 1.999e-04   fission_err: 0.000e+00
# iter 059:  lamb: 0.82321  Keff:1.21476   lambda_err: 1.873e-04   fission_err: 0.000e+00
# iter 060:  lamb: 0.82306  Keff:1.21497   lambda_err: 1.756e-04   fission_err: 0.000e+00
# iter 061:  lamb: 0.82293  Keff:1.21517   lambda_err: 1.647e-04   fission_err: 0.000e+00
# iter 062:  lamb: 0.82280  Keff:1.21536   lambda_err: 1.546e-04   fission_err: 0.000e+00
# iter 063:  lamb: 0.82268  Keff:1.21554   lambda_err: 1.453e-04   fission_err: 0.000e+00
# iter 064:  lamb: 0.82257  Keff:1.21570   lambda_err: 1.366e-04   fission_err: 0.000e+00
# iter 065:  lamb: 0.82246  Keff:1.21586   lambda_err: 1.286e-04   fission_err: 0.000e+00
# iter 066:  lamb: 0.82236  Keff:1.21601   lambda_err: 1.211e-04   fission_err: 0.000e+00
# iter 067:  lamb: 0.82227  Keff:1.21615   lambda_err: 1.141e-04   fission_err: 0.000e+00
# iter 068:  lamb: 0.82218  Keff:1.21628   lambda_err: 1.076e-04   fission_err: 0.000e+00
# iter 069:  lamb: 0.82210  Keff:1.21640   lambda_err: 1.015e-04   fission_err: 0.000e+00
# iter 070:  lamb: 0.82202  Keff:1.21652   lambda_err: 9.585e-05   fission_err: 0.000e+00
# iter 071:  lamb: 0.82194  Keff:1.21663   lambda_err: 9.057e-05   fission_err: 0.000e+00
# iter 072:  lamb: 0.82187  Keff:1.21673   lambda_err: 8.563e-05   fission_err: 0.000e+00
# iter 073:  lamb: 0.82181  Keff:1.21683   lambda_err: 8.101e-05   fission_err: 0.000e+00
# iter 074:  lamb: 0.82174  Keff:1.21692   lambda_err: 7.669e-05   fission_err: 0.000e+00
# iter 075:  lamb: 0.82169  Keff:1.21701   lambda_err: 7.264e-05   fission_err: 0.000e+00
# iter 076:  lamb: 0.82163  Keff:1.21709   lambda_err: 6.885e-05   fission_err: 0.000e+00
# iter 077:  lamb: 0.82157  Keff:1.21717   lambda_err: 6.529e-05   fission_err: 0.000e+00
# iter 078:  lamb: 0.82152  Keff:1.21725   lambda_err: 6.194e-05   fission_err: 0.000e+00
# iter 079:  lamb: 0.82148  Keff:1.21732   lambda_err: 5.880e-05   fission_err: 0.000e+00
# iter 080:  lamb: 0.82143  Keff:1.21739   lambda_err: 5.585e-05   fission_err: 0.000e+00
# iter 081:  lamb: 0.82139  Keff:1.21745   lambda_err: 5.308e-05   fission_err: 0.000e+00
# iter 082:  lamb: 0.82134  Keff:1.21752   lambda_err: 5.046e-05   fission_err: 0.000e+00
# iter 083:  lamb: 0.82131  Keff:1.21757   lambda_err: 4.800e-05   fission_err: 0.000e+00
# iter 084:  lamb: 0.82127  Keff:1.21763   lambda_err: 4.568e-05   fission_err: 0.000e+00
# iter 085:  lamb: 0.82123  Keff:1.21768   lambda_err: 4.349e-05   fission_err: 0.000e+00
# iter 086:  lamb: 0.82120  Keff:1.21773   lambda_err: 4.143e-05   fission_err: 0.000e+00
# iter 087:  lamb: 0.82117  Keff:1.21778   lambda_err: 3.947e-05   fission_err: 0.000e+00
# iter 088:  lamb: 0.82113  Keff:1.21783   lambda_err: 3.763e-05   fission_err: 0.000e+00
# iter 089:  lamb: 0.82111  Keff:1.21787   lambda_err: 3.589e-05   fission_err: 0.000e+00
# iter 090:  lamb: 0.82108  Keff:1.21791   lambda_err: 3.424e-05   fission_err: 0.000e+00
# iter 091:  lamb: 0.82105  Keff:1.21795   lambda_err: 3.268e-05   fission_err: 0.000e+00
# iter 092:  lamb: 0.82102  Keff:1.21799   lambda_err: 3.120e-05   fission_err: 0.000e+00
# iter 093:  lamb: 0.82100  Keff:1.21803   lambda_err: 2.980e-05   fission_err: 0.000e+00
# iter 094:  lamb: 0.82098  Keff:1.21806   lambda_err: 2.848e-05   fission_err: 0.000e+00
# iter 095:  lamb: 0.82095  Keff:1.21809   lambda_err: 2.722e-05   fission_err: 0.000e+00
# iter 096:  lamb: 0.82093  Keff:1.21813   lambda_err: 2.602e-05   fission_err: 0.000e+00
# iter 097:  lamb: 0.82091  Keff:1.21816   lambda_err: 2.489e-05   fission_err: 0.000e+00
# iter 098:  lamb: 0.82089  Keff:1.21819   lambda_err: 2.381e-05   fission_err: 0.000e+00
# iter 099:  lamb: 0.82087  Keff:1.21821   lambda_err: 2.279e-05   fission_err: 0.000e+00
# iter 100:  lamb: 0.82086  Keff:1.21824   lambda_err: 2.182e-05   fission_err: 0.000e+00
# iter 101:  lamb: 0.82084  Keff:1.21826   lambda_err: 2.090e-05   fission_err: 0.000e+00
# iter 102:  lamb: 0.82082  Keff:1.21829   lambda_err: 2.002e-05   fission_err: 0.000e+00
# iter 103:  lamb: 0.82081  Keff:1.21831   lambda_err: 1.918e-05   fission_err: 0.000e+00
# iter 104:  lamb: 0.82079  Keff:1.21834   lambda_err: 1.839e-05   fission_err: 0.000e+00
# ...
# iter 323:  Keff:1.21856   lambda_err: 1.193e-06   fission_err: 6.498e-05
# iter 324:  Keff:1.21856   lambda_err: 1.178e-06   fission_err: 6.422e-05
# iter 325:  Keff:1.21857   lambda_err: 1.163e-06   fission_err: 6.346e-05
# iter 326:  Keff:1.21857   lambda_err: 1.149e-06   fission_err: 6.271e-05
# iter 327:  Keff:1.21857   lambda_err: 1.134e-06   fission_err: 6.197e-05
# iter 328:  Keff:1.21857   lambda_err: 1.120e-06   fission_err: 6.124e-05
# iter 329:  Keff:1.21857   lambda_err: 1.106e-06   fission_err: 6.051e-05
# iter 330:  Keff:1.21857   lambda_err: 1.092e-06   fission_err: 5.980e-05
# iter 331:  Keff:1.21857   lambda_err: 1.079e-06   fission_err: 5.909e-05
# iter 332:  Keff:1.21858   lambda_err: 1.065e-06   fission_err: 5.840e-05
# iter 333:  Keff:1.21858   lambda_err: 1.052e-06   fission_err: 5.771e-05
# iter 334:  Keff:1.21858   lambda_err: 1.039e-06   fission_err: 5.703e-05
# iter 335:  Keff:1.21858   lambda_err: 1.026e-06   fission_err: 5.635e-05
# iter 336:  Keff:1.21858   lambda_err: 1.013e-06   fission_err: 5.569e-05
# iter 337:  Keff:1.21858   lambda_err: 1.000e-06   fission_err: 5.503e-05
# iter 338:  Keff:1.21858   lambda_err: 9.878e-07   fission_err: 5.438e-05
# iter 339:  Keff:1.21858   lambda_err: 9.755e-07   fission_err: 5.374e-05
# iter 340:  Keff:1.21859   lambda_err: 9.634e-07   fission_err: 5.311e-05
# iter 341:  Keff:1.21859   lambda_err: 9.515e-07   fission_err: 5.248e-05
# iter 342:  Keff:1.21859   lambda_err: 9.397e-07   fission_err: 5.186e-05
# iter 343:  Keff:1.21859   lambda_err: 9.280e-07   fission_err: 5.125e-05
# iter 344:  Keff:1.21859   lambda_err: 9.165e-07   fission_err: 5.065e-05
# iter 345:  Keff:1.21859   lambda_err: 9.051e-07   fission_err: 5.005e-05
# iter 346:  Keff:1.21859   lambda_err: 8.939e-07   fission_err: 4.946e-05
# iter 347:  Keff:1.21859   lambda_err: 8.829e-07   fission_err: 4.888e-05
# iter 348:  Keff:1.21859   lambda_err: 8.720e-07   fission_err: 4.831e-05
# iter 349:  Keff:1.21860   lambda_err: 8.612e-07   fission_err: 4.774e-05
# iter 350:  Keff:1.21860   lambda_err: 8.506e-07   fission_err: 4.718e-05
# iter 351:  Keff:1.21860   lambda_err: 8.401e-07   fission_err: 4.662e-05
# iter 352:  Keff:1.21860   lambda_err: 8.297e-07   fission_err: 4.607e-05
# iter 353:  Keff:1.21860   lambda_err: 8.195e-07   fission_err: 4.553e-05
# iter 354:  Keff:1.21860   lambda_err: 8.094e-07   fission_err: 4.500e-05
# iter 355:  Keff:1.21860   lambda_err: 7.994e-07   fission_err: 4.447e-05
# iter 356:  Keff:1.21860   lambda_err: 7.896e-07   fission_err: 4.394e-05
# iter 357:  Keff:1.21860   lambda_err: 7.799e-07   fission_err: 4.343e-05
# iter 358:  Keff:1.21860   lambda_err: 7.703e-07   fission_err: 4.292e-05
# iter 359:  Keff:1.21861   lambda_err: 7.608e-07   fission_err: 4.241e-05
# iter 360:  Keff:1.21861   lambda_err: 7.515e-07   fission_err: 4.191e-05
# iter 361:  Keff:1.21861   lambda_err: 7.422e-07   fission_err: 4.142e-05
# iter 362:  Keff:1.21861   lambda_err: 7.331e-07   fission_err: 4.094e-05
# iter 363:  Keff:1.21861   lambda_err: 7.241e-07   fission_err: 4.045e-05
# iter 364:  Keff:1.21861   lambda_err: 7.153e-07   fission_err: 3.998e-05
# iter 365:  Keff:1.21861   lambda_err: 7.065e-07   fission_err: 3.951e-05
# iter 366:  Keff:1.21861   lambda_err: 6.979e-07   fission_err: 3.905e-05
# iter 367:  Keff:1.21861   lambda_err: 6.893e-07   fission_err: 3.859e-05
# iter 368:  Keff:1.21861   lambda_err: 6.809e-07   fission_err: 3.813e-05
# iter 369:  Keff:1.21861   lambda_err: 6.726e-07   fission_err: 3.769e-05
# iter 370:  Keff:1.21861   lambda_err: 6.643e-07   fission_err: 3.725e-05
# iter 371:  Keff:1.21862   lambda_err: 6.562e-07   fission_err: 3.681e-05
# iter 372:  Keff:1.21862   lambda_err: 6.482e-07   fission_err: 3.638e-05
# iter 373:  Keff:1.21862   lambda_err: 6.403e-07   fission_err: 3.595e-05
# iter 374:  Keff:1.21862   lambda_err: 6.325e-07   fission_err: 3.553e-05
# iter 375:  Keff:1.21862   lambda_err: 6.248e-07   fission_err: 3.511e-05
# iter 376:  Keff:1.21862   lambda_err: 6.172e-07   fission_err: 3.470e-05
# iter 377:  Keff:1.21862   lambda_err: 6.096e-07   fission_err: 3.429e-05
# iter 378:  Keff:1.21862   lambda_err: 6.022e-07   fission_err: 3.389e-05
# iter 379:  Keff:1.21862   lambda_err: 5.949e-07   fission_err: 3.349e-05
# iter 380:  Keff:1.21862   lambda_err: 5.876e-07   fission_err: 3.310e-05
# iter 381:  Keff:1.21862   lambda_err: 5.805e-07   fission_err: 3.271e-05
# iter 382:  Keff:1.21862   lambda_err: 5.734e-07   fission_err: 3.233e-05
# iter 383:  Keff:1.21862   lambda_err: 5.665e-07   fission_err: 3.195e-05
# iter 384:  Keff:1.21862   lambda_err: 5.596e-07   fission_err: 3.158e-05
# iter 385:  Keff:1.21863   lambda_err: 5.528e-07   fission_err: 3.121e-05
# iter 386:  Keff:1.21863   lambda_err: 5.461e-07   fission_err: 3.084e-05
# iter 387:  Keff:1.21863   lambda_err: 5.394e-07   fission_err: 3.048e-05
# iter 388:  Keff:1.21863   lambda_err: 5.329e-07   fission_err: 3.013e-05
# iter 389:  Keff:1.21863   lambda_err: 5.264e-07   fission_err: 2.977e-05
# iter 390:  Keff:1.21863   lambda_err: 5.200e-07   fission_err: 2.942e-05
# iter 391:  Keff:1.21863   lambda_err: 5.137e-07   fission_err: 2.908e-05
# iter 392:  Keff:1.21863   lambda_err: 5.075e-07   fission_err: 2.874e-05
# iter 393:  Keff:1.21863   lambda_err: 5.014e-07   fission_err: 2.840e-05
# iter 394:  Keff:1.21863   lambda_err: 4.953e-07   fission_err: 2.807e-05
# iter 395:  Keff:1.21863   lambda_err: 4.893e-07   fission_err: 2.774e-05
# iter 396:  Keff:1.21863   lambda_err: 4.834e-07   fission_err: 2.742e-05
# iter 397:  Keff:1.21863   lambda_err: 4.775e-07   fission_err: 2.710e-05
# iter 398:  Keff:1.21863   lambda_err: 4.717e-07   fission_err: 2.678e-05
# iter 399:  Keff:1.21863   lambda_err: 4.660e-07   fission_err: 2.647e-05
# iter 400:  Keff:1.21863   lambda_err: 4.604e-07   fission_err: 2.616e-05
# iter 401:  Keff:1.21864   lambda_err: 4.548e-07   fission_err: 2.585e-05
# iter 402:  Keff:1.21864   lambda_err: 4.493e-07   fission_err: 2.555e-05
# iter 403:  Keff:1.21864   lambda_err: 4.439e-07   fission_err: 2.525e-05
# iter 404:  Keff:1.21864   lambda_err: 4.386e-07   fission_err: 2.496e-05
# iter 405:  Keff:1.21864   lambda_err: 4.333e-07   fission_err: 2.467e-05
# iter 406:  Keff:1.21864   lambda_err: 4.280e-07   fission_err: 2.438e-05
# iter 407:  Keff:1.21864   lambda_err: 4.229e-07   fission_err: 2.409e-05
# iter 408:  Keff:1.21864   lambda_err: 4.178e-07   fission_err: 2.381e-05
# iter 409:  Keff:1.21864   lambda_err: 4.127e-07   fission_err: 2.354e-05
# iter 410:  Keff:1.21864   lambda_err: 4.078e-07   fission_err: 2.326e-05
# iter 411:  Keff:1.21864   lambda_err: 4.029e-07   fission_err: 2.299e-05
# iter 412:  Keff:1.21864   lambda_err: 3.980e-07   fission_err: 2.272e-05
# iter 413:  Keff:1.21864   lambda_err: 3.932e-07   fission_err: 2.246e-05
# iter 414:  Keff:1.21864   lambda_err: 3.885e-07   fission_err: 2.219e-05
# iter 415:  Keff:1.21864   lambda_err: 3.838e-07   fission_err: 2.194e-05
# iter 416:  Keff:1.21864   lambda_err: 3.792e-07   fission_err: 2.168e-05
# iter 417:  Keff:1.21864   lambda_err: 3.746e-07   fission_err: 2.143e-05
# iter 418:  Keff:1.21864   lambda_err: 3.701e-07   fission_err: 2.118e-05
# iter 419:  Keff:1.21864   lambda_err: 3.657e-07   fission_err: 2.093e-05
# iter 420:  Keff:1.21864   lambda_err: 3.613e-07   fission_err: 2.069e-05
# iter 421:  Keff:1.21865   lambda_err: 3.569e-07   fission_err: 2.045e-05
# iter 422:  Keff:1.21865   lambda_err: 3.526e-07   fission_err: 2.021e-05
# iter 423:  Keff:1.21865   lambda_err: 3.484e-07   fission_err: 1.997e-05
# iter 424:  Keff:1.21865   lambda_err: 3.442e-07   fission_err: 1.974e-05
# iter 425:  Keff:1.21865   lambda_err: 3.401e-07   fission_err: 1.951e-05
# iter 426:  Keff:1.21865   lambda_err: 3.360e-07   fission_err: 1.928e-05
# iter 427:  Keff:1.21865   lambda_err: 3.320e-07   fission_err: 1.906e-05
# iter 428:  Keff:1.21865   lambda_err: 3.280e-07   fission_err: 1.884e-05
# iter 429:  Keff:1.21865   lambda_err: 3.240e-07   fission_err: 1.862e-05
# iter 430:  Keff:1.21865   lambda_err: 3.202e-07   fission_err: 1.840e-05
# iter 431:  Keff:1.21865   lambda_err: 3.163e-07   fission_err: 1.819e-05
# iter 432:  Keff:1.21865   lambda_err: 3.125e-07   fission_err: 1.798e-05
# iter 433:  Keff:1.21865   lambda_err: 3.088e-07   fission_err: 1.777e-05
# iter 434:  Keff:1.21865   lambda_err: 3.051e-07   fission_err: 1.756e-05
# iter 435:  Keff:1.21865   lambda_err: 3.014e-07   fission_err: 1.736e-05
# iter 436:  Keff:1.21865   lambda_err: 2.978e-07   fission_err: 1.715e-05
# iter 437:  Keff:1.21865   lambda_err: 2.942e-07   fission_err: 1.696e-05
# iter 438:  Keff:1.21865   lambda_err: 2.907e-07   fission_err: 1.676e-05
# iter 439:  Keff:1.21865   lambda_err: 2.872e-07   fission_err: 1.656e-05
# iter 440:  Keff:1.21865   lambda_err: 2.838e-07   fission_err: 1.637e-05
# iter 441:  Keff:1.21865   lambda_err: 2.804e-07   fission_err: 1.618e-05
# iter 442:  Keff:1.21865   lambda_err: 2.770e-07   fission_err: 1.599e-05
# iter 443:  Keff:1.21865   lambda_err: 2.737e-07   fission_err: 1.581e-05
# iter 444:  Keff:1.21865   lambda_err: 2.705e-07   fission_err: 1.562e-05
# iter 445:  Keff:1.21865   lambda_err: 2.672e-07   fission_err: 1.544e-05
# iter 446:  Keff:1.21865   lambda_err: 2.640e-07   fission_err: 1.526e-05
# iter 447:  Keff:1.21865   lambda_err: 2.609e-07   fission_err: 1.509e-05
# iter 448:  Keff:1.21865   lambda_err: 2.578e-07   fission_err: 1.491e-05
# iter 449:  Keff:1.21866   lambda_err: 2.547e-07   fission_err: 1.474e-05
# iter 450:  Keff:1.21866   lambda_err: 2.516e-07   fission_err: 1.457e-05
# iter 451:  Keff:1.21866   lambda_err: 2.486e-07   fission_err: 1.440e-05
# iter 452:  Keff:1.21866   lambda_err: 2.457e-07   fission_err: 1.423e-05
# iter 453:  Keff:1.21866   lambda_err: 2.427e-07   fission_err: 1.407e-05
# iter 454:  Keff:1.21866   lambda_err: 2.398e-07   fission_err: 1.390e-05
# iter 455:  Keff:1.21866   lambda_err: 2.370e-07   fission_err: 1.374e-05
# iter 456:  Keff:1.21866   lambda_err: 2.341e-07   fission_err: 1.358e-05
# iter 457:  Keff:1.21866   lambda_err: 2.313e-07   fission_err: 1.343e-05
# iter 458:  Keff:1.21866   lambda_err: 2.286e-07   fission_err: 1.327e-05
# iter 459:  Keff:1.21866   lambda_err: 2.258e-07   fission_err: 1.312e-05
# iter 460:  Keff:1.21866   lambda_err: 2.232e-07   fission_err: 1.297e-05
# iter 461:  Keff:1.21866   lambda_err: 2.205e-07   fission_err: 1.282e-05
# iter 462:  Keff:1.21866   lambda_err: 2.179e-07   fission_err: 1.267e-05
# iter 463:  Keff:1.21866   lambda_err: 2.153e-07   fission_err: 1.252e-05
# iter 464:  Keff:1.21866   lambda_err: 2.127e-07   fission_err: 1.238e-05
# iter 465:  Keff:1.21866   lambda_err: 2.102e-07   fission_err: 1.223e-05
# iter 466:  Keff:1.21866   lambda_err: 2.077e-07   fission_err: 1.209e-05
# iter 467:  Keff:1.21866   lambda_err: 2.052e-07   fission_err: 1.195e-05
# iter 468:  Keff:1.21866   lambda_err: 2.027e-07   fission_err: 1.181e-05
# iter 469:  Keff:1.21866   lambda_err: 2.003e-07   fission_err: 1.168e-05
# iter 470:  Keff:1.21866   lambda_err: 1.979e-07   fission_err: 1.154e-05
# iter 471:  Keff:1.21866   lambda_err: 1.956e-07   fission_err: 1.141e-05
# iter 472:  Keff:1.21866   lambda_err: 1.932e-07   fission_err: 1.128e-05
# iter 473:  Keff:1.21866   lambda_err: 1.909e-07   fission_err: 1.115e-05
# iter 474:  Keff:1.21866   lambda_err: 1.887e-07   fission_err: 1.102e-05
# iter 475:  Keff:1.21866   lambda_err: 1.864e-07   fission_err: 1.089e-05
# iter 476:  Keff:1.21866   lambda_err: 1.842e-07   fission_err: 1.077e-05
# iter 477:  Keff:1.21866   lambda_err: 1.820e-07   fission_err: 1.064e-05
# iter 478:  Keff:1.21866   lambda_err: 1.798e-07   fission_err: 1.052e-05
# iter 479:  Keff:1.21866   lambda_err: 1.777e-07   fission_err: 1.040e-05
# iter 480:  Keff:1.21866   lambda_err: 1.756e-07   fission_err: 1.028e-05
# iter 481:  Keff:1.21866   lambda_err: 1.735e-07   fission_err: 1.016e-05
# iter 482:  Keff:1.21866   lambda_err: 1.714e-07   fission_err: 1.004e-05
# iter 483:  Keff:1.21866   lambda_err: 1.694e-07   fission_err: 9.926e-06
# iter 484:  Keff:1.21866   lambda_err: 1.674e-07   fission_err: 9.811e-06
# iter 485:  Keff:1.21866   lambda_err: 1.654e-07   fission_err: 9.698e-06
# iter 486:  Keff:1.21866   lambda_err: 1.634e-07   fission_err: 9.587e-06
# iter 487:  Keff:1.21866   lambda_err: 1.615e-07   fission_err: 9.476e-06
# iter 488:  Keff:1.21866   lambda_err: 1.596e-07   fission_err: 9.367e-06
# iter 489:  Keff:1.21867   lambda_err: 1.577e-07   fission_err: 9.259e-06
# iter 490:  Keff:1.21867   lambda_err: 1.558e-07   fission_err: 9.153e-06
# iter 491:  Keff:1.21867   lambda_err: 1.539e-07   fission_err: 9.048e-06
# iter 492:  Keff:1.21867   lambda_err: 1.521e-07   fission_err: 8.944e-06
# iter 493:  Keff:1.21867   lambda_err: 1.503e-07   fission_err: 8.841e-06
# iter 494:  Keff:1.21867   lambda_err: 1.485e-07   fission_err: 8.739e-06
# iter 495:  Keff:1.21867   lambda_err: 1.468e-07   fission_err: 8.639e-06
# iter 496:  Keff:1.21867   lambda_err: 1.450e-07   fission_err: 8.539e-06
# iter 497:  Keff:1.21867   lambda_err: 1.433e-07   fission_err: 8.441e-06
# iter 498:  Keff:1.21867   lambda_err: 1.416e-07   fission_err: 8.344e-06
# iter 499:  Keff:1.21867   lambda_err: 1.399e-07   fission_err: 8.249e-06
# iter 500:  Keff:1.21867   lambda_err: 1.382e-07   fission_err: 8.154e-06
# iter 501:  Keff:1.21867   lambda_err: 1.366e-07   fission_err: 8.060e-06
# iter 502:  Keff:1.21867   lambda_err: 1.350e-07   fission_err: 7.968e-06
# iter 503:  Keff:1.21867   lambda_err: 1.334e-07   fission_err: 7.876e-06
# iter 504:  Keff:1.21867   lambda_err: 1.318e-07   fission_err: 7.786e-06
# iter 505:  Keff:1.21867   lambda_err: 1.302e-07   fission_err: 7.697e-06
# iter 506:  Keff:1.21867   lambda_err: 1.287e-07   fission_err: 7.609e-06
# iter 507:  Keff:1.21867   lambda_err: 1.272e-07   fission_err: 7.521e-06
# iter 508:  Keff:1.21867   lambda_err: 1.256e-07   fission_err: 7.435e-06
# iter 509:  Keff:1.21867   lambda_err: 1.242e-07   fission_err: 7.350e-06
# iter 510:  Keff:1.21867   lambda_err: 1.227e-07   fission_err: 7.266e-06
# iter 511:  Keff:1.21867   lambda_err: 1.212e-07   fission_err: 7.183e-06
# iter 512:  Keff:1.21867   lambda_err: 1.198e-07   fission_err: 7.101e-06
# iter 513:  Keff:1.21867   lambda_err: 1.184e-07   fission_err: 7.019e-06
# iter 514:  Keff:1.21867   lambda_err: 1.170e-07   fission_err: 6.939e-06
# iter 515:  Keff:1.21867   lambda_err: 1.156e-07   fission_err: 6.860e-06
# iter 516:  Keff:1.21867   lambda_err: 1.142e-07   fission_err: 6.781e-06
# iter 517:  Keff:1.21867   lambda_err: 1.129e-07   fission_err: 6.704e-06
# iter 518:  Keff:1.21867   lambda_err: 1.115e-07   fission_err: 6.627e-06
# iter 519:  Keff:1.21867   lambda_err: 1.102e-07   fission_err: 6.551e-06
# iter 520:  Keff:1.21867   lambda_err: 1.089e-07   fission_err: 6.477e-06
# iter 521:  Keff:1.21867   lambda_err: 1.076e-07   fission_err: 6.403e-06
# iter 522:  Keff:1.21867   lambda_err: 1.063e-07   fission_err: 6.330e-06
# iter 523:  Keff:1.21867   lambda_err: 1.051e-07   fission_err: 6.257e-06
# iter 524:  Keff:1.21867   lambda_err: 1.038e-07   fission_err: 6.186e-06
# iter 525:  Keff:1.21867   lambda_err: 1.026e-07   fission_err: 6.115e-06
# iter 526:  Keff:1.21867   lambda_err: 1.014e-07   fission_err: 6.046e-06
# iter 527:  Keff:1.21867   lambda_err: 1.002e-07   fission_err: 5.977e-06
# iter 528:  Keff:1.21867   lambda_err: 9.898e-08   fission_err: 5.909e-06
# ####################### kEFF #########################################
# cmfd-sn(8):             iter 95  keff: 1.2189952718442871
# nmesh_per_region:  16
# cmfd-sn(2):             iter 92  keff: 1.2192004224644908 keff diff (pcm):  20.51506202036535
# cmfd-sn(4):             iter 92  keff: 1.2190256764351242 keff diff (pcm):  3.0404590837029843
# cmfd-sn(6):             iter 94  keff: 1.219003128370421 keff diff (pcm):  0.7856526133886987
# cmfd-alone (diffusion): iter 63  keff: 1.218871748733678 keff diff (pcm):  -12.352311060914722
# cmfd-pn:                iter 88  keff: 1.2186810696576833 keff diff (pcm):  -31.420218660382915
# sn-alone:               iter 372  keff: 1.2189924183746095 keff diff (pcm):  -0.2853469677654985
# pn-alone:               iter 529  keff: 1.2186710613222362 keff diff (pcm):  -32.421052205089396
# ######################################################################

# %%
print("nmesh_per_region: ", nmesh_per_region)
print("cmfd-sn(2):              keff:", keff_sn2)
print("cmfd-alone (diffusion):  keff:", keff_cmfd, "keff diff (pcm): ", (keff_cmfd-keff_sn2)*1e5)

fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.plot(x, phisn2[:,0])
ax1.plot(x, phicmfd[:,0])
ax1.set_xlabel('x (cm)')
ax1.set_ylabel('phi', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend(["Sn(2)", "DF"])

ax2 = ax1.twinx()
color = 'tab:green'
plt.plot(x, abs(phicmfd[:,0]-phisn2[:,0]) / phisn2[:,0] *100, color=color, linestyle='dashed')
ax2.set_ylabel('RE(%)', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title("Group 1")
fig.tight_layout()
plt.show()

fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.plot(x, phisn2[:,1])
ax1.plot(x, phicmfd[:,1])
ax1.set_xlabel('x (cm)')
ax1.set_ylabel('phi', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend(["Sn(2)", "DF"])

ax2 = ax1.twinx()
color = 'tab:green'
plt.plot(x, abs(phicmfd[:,1]-phisn2[:,1]) / phisn2[:,1] *100, color=color, linestyle='dashed')
ax2.set_ylabel('RE(%)', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title("Group 2")
fig.tight_layout()
plt.show()


print("cmfd-sn(4):              keff:", keff_sn4)
print("cmfd-pn:                 keff:", keff_pn, "keff diff (pcm): ", (keff_pn-keff_sn4)*1e5)

fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.plot(x, phisn4[:,0])
ax1.plot(x, phipn[:,0])
ax1.set_xlabel('x (cm)')
ax1.set_ylabel('phi', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend(["Sn(4)", "Pn3"])

ax2 = ax1.twinx()
color = 'tab:green'
plt.plot(x, abs(phipn[:,0]-phisn4[:,0]) / phisn4[:,0] *100, color=color, linestyle='dashed')
ax2.set_ylabel('RE(%)', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title("Group 1")
fig.tight_layout()
plt.show()

fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.plot(x, phisn4[:,1])
ax1.plot(x, phipn[:,1])
ax1.set_xlabel('x (cm)')
ax1.set_ylabel('phi', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend(["Sn(4)", "Pn3"])

ax2 = ax1.twinx()
color = 'tab:green'
plt.plot(x, abs(phipn[:,1]-phisn4[:,1]) / phisn4[:,1] *100, color=color, linestyle='dashed')
ax2.set_ylabel('RE(%)', color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title("Group 2")
fig.tight_layout()
plt.show()
# Out:
# nmesh_per_region:  16
# cmfd-sn(2):              keff: 1.2192004224644908
# cmfd-alone (diffusion):  keff: 1.218871748733678 keff diff (pcm):  -32.86737308128007
# cmfd-sn(4):              keff: 1.2190256764351242
# cmfd-pn:                 keff: 1.2186810696576833 keff diff (pcm):  -34.4606777440859
